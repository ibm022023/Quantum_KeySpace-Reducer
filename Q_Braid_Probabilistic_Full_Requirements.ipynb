# %%
# !pip3 install qiskit_ibm_runtime && pip3 install qiskit==0.24.0
# Out:
# Collecting qiskit_ibm_runtime
#   Using cached qiskit_ibm_runtime-0.46.1-py3-none-any.whl.metadata (21 kB)
# Collecting requests>=2.32.4 (from qiskit_ibm_runtime)
#   Using cached requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting requests-ntlm>=1.1.0 (from qiskit_ibm_runtime)
#   Using cached requests_ntlm-1.3.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: numpy>=1.26 in /opt/conda/lib/python3.11/site-packages (from qiskit_ibm_runtime) (1.26.4)
# Collecting urllib3>=2.4.0 (from qiskit_ibm_runtime)
#   Using cached urllib3-2.7.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: python-dateutil>=2.9.0 in /opt/conda/lib/python3.11/site-packages (from qiskit_ibm_runtime) (2.9.0)
# Collecting ibm-platform-services>=0.55.3 (from qiskit_ibm_runtime)
#   Using cached ibm_platform_services-0.75.0-py3-none-any.whl.metadata (9.2 kB)
# Collecting ibm-quantum-schemas>=0.5.20260320 (from qiskit_ibm_runtime)
#   Using cached ibm_quantum_schemas-0.7.20260419-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: pydantic>=2.7.0 in /opt/conda/lib/python3.11/site-packages (from qiskit_ibm_runtime) (2.12.5)
# Requirement already satisfied: qiskit>=2.2.0 in /opt/conda/lib/python3.11/site-packages (from qiskit_ibm_runtime) (2.3.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from qiskit_ibm_runtime) (24.0)
# Collecting pybase64>=1.4 (from qiskit_ibm_runtime)
#   Using cached pybase64-1.4.3-cp311-cp311-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (8.7 kB)
# Collecting samplomatic>=0.13.0 (from qiskit_ibm_runtime)
#   Using cached samplomatic-0.18.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting ibm_cloud_sdk_core<4.0.0,>=3.24.4 (from ibm-platform-services>=0.55.3->qiskit_ibm_runtime)
#   Using cached ibm_cloud_sdk_core-3.24.4-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from pydantic>=2.7.0->qiskit_ibm_runtime) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/conda/lib/python3.11/site-packages (from pydantic>=2.7.0->qiskit_ibm_runtime) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /opt/conda/lib/python3.11/site-packages (from pydantic>=2.7.0->qiskit_ibm_runtime) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/conda/lib/python3.11/site-packages (from pydantic>=2.7.0->qiskit_ibm_runtime) (0.4.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.9.0->qiskit_ibm_runtime) (1.16.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /opt/conda/lib/python3.11/site-packages (from qiskit>=2.2.0->qiskit_ibm_runtime) (0.17.1)
# Requirement already satisfied: scipy>=1.5 in /opt/conda/lib/python3.11/site-packages (from qiskit>=2.2.0->qiskit_ibm_runtime) (1.17.1)
# Requirement already satisfied: dill>=0.3 in /opt/conda/lib/python3.11/site-packages (from qiskit>=2.2.0->qiskit_ibm_runtime) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/conda/lib/python3.11/site-packages (from qiskit>=2.2.0->qiskit_ibm_runtime) (5.7.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.32.4->qiskit_ibm_runtime) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests>=2.32.4->qiskit_ibm_runtime) (3.7)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/conda/lib/python3.11/site-packages (from requests>=2.32.4->qiskit_ibm_runtime) (2026.2.25)
# Requirement already satisfied: cryptography>=1.3 in /opt/conda/lib/python3.11/site-packages (from requests-ntlm>=1.1.0->qiskit_ibm_runtime) (42.0.7)
# Collecting pyspnego>=0.4.0 (from requests-ntlm>=1.1.0->qiskit_ibm_runtime)
#   Using cached pyspnego-0.12.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting orjson>=3.9.0 (from samplomatic>=0.13.0->qiskit_ibm_runtime)
#   Using cached orjson-3.11.9-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (41 kB)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.11/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit_ibm_runtime) (1.16.0)
# Requirement already satisfied: PyJWT<3.0.0,>=2.11.0 in /opt/conda/lib/python3.11/site-packages (from ibm_cloud_sdk_core<4.0.0,>=3.24.4->ibm-platform-services>=0.55.3->qiskit_ibm_runtime) (2.12.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit_ibm_runtime) (2.22)
# Using cached qiskit_ibm_runtime-0.46.1-py3-none-any.whl (1.5 MB)
# Using cached ibm_platform_services-0.75.0-py3-none-any.whl (386 kB)
# Using cached ibm_quantum_schemas-0.7.20260419-py3-none-any.whl (102 kB)
# Using cached pybase64-1.4.3-cp311-cp311-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (71 kB)
# Using cached requests-2.33.1-py3-none-any.whl (64 kB)
# Using cached requests_ntlm-1.3.0-py3-none-any.whl (6.6 kB)
# Using cached samplomatic-0.18.0-py3-none-any.whl (212 kB)
# Using cached urllib3-2.7.0-py3-none-any.whl (131 kB)
# Using cached ibm_cloud_sdk_core-3.24.4-py3-none-any.whl (75 kB)
# Using cached orjson-3.11.9-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (133 kB)
# Using cached pyspnego-0.12.1-py3-none-any.whl (130 kB)
# Installing collected packages: urllib3, pybase64, orjson, requests, samplomatic, pyspnego, ibm_cloud_sdk_core, requests-ntlm, ibm-quantum-schemas, ibm-platform-services, qiskit_ibm_runtime
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.2.1
#     Uninstalling urllib3-2.2.1:
#       Successfully uninstalled urllib3-2.2.1
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
# Successfully installed ibm-platform-services-0.75.0 ibm-quantum-schemas-0.7.20260419 ibm_cloud_sdk_core-3.24.4 orjson-3.11.9 pybase64-1.4.3 pyspnego-0.12.1 qiskit_ibm_runtime-0.46.1 requests-2.33.1 requests-ntlm-1.3.0 samplomatic-0.18.0 urllib3-2.7.0
# Collecting qiskit==0.24.0
#   Using cached qiskit-0.24.0.tar.gz (4.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting qiskit-terra==0.16.4 (from qiskit==0.24.0)
#   Using cached qiskit-terra-0.16.4.tar.gz (8.1 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting qiskit-aer==0.7.6 (from qiskit==0.24.0)
#   Using cached qiskit-aer-0.7.6.tar.gz (6.4 MB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [60 lines of output]
#       Collecting Cython>=0.27.1
#         Using cached cython-3.2.4-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (7.5 kB)
#       Using cached cython-3.2.4-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.4 MB)
#       Installing collected packages: Cython
#       Successfully installed Cython-3.2.4
#       Collecting urllib3<1.26
#         Using cached urllib3-1.25.11-py2.py3-none-any.whl.metadata (41 kB)
#       Using cached urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#       Installing collected packages: urllib3
#         Attempting uninstall: urllib3
#           Found existing installation: urllib3 2.7.0
#           Uninstalling urllib3-2.7.0:
#             Successfully uninstalled urllib3-2.7.0
#       ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
#       requests 2.33.1 requires urllib3<3,>=1.26, but you have urllib3 1.25.11 which is incompatible.
#       qiskit-ibm-runtime 0.46.1 requires urllib3>=2.4.0, but you have urllib3 1.25.11 which is incompatible.
#       ibm-cloud-sdk-core 3.24.4 requires urllib3<3.0.0,>=2.4.0, but you have urllib3 1.25.11 which is incompatible.
#       Successfully installed urllib3-1.25.11
#       Collecting conan
#         Using cached conan-2.28.1-py3-none-any.whl.metadata (8.6 kB)
#       Requirement already satisfied: requests<3.0.0,>=2.25 in /opt/conda/lib/python3.11/site-packages (from conan) (2.33.1)
#       Collecting urllib3<3.0,>=1.26.6 (from conan)
#         Using cached urllib3-2.7.0-py3-none-any.whl.metadata (6.9 kB)
#       Requirement already satisfied: colorama<0.5.0,>=0.4.3 in /opt/conda/lib/python3.11/site-packages (from conan) (0.4.6)
#       Requirement already satisfied: PyYAML<7.0,>=6.0 in /opt/conda/lib/python3.11/site-packages (from conan) (6.0.1)
#       Collecting patch-ng<1.20,>=1.18.0 (from conan)
#         Using cached patch_ng-1.19.1-py3-none-any.whl.metadata (3.2 kB)
#       Collecting fasteners>=0.15 (from conan)
#         Using cached fasteners-0.20-py3-none-any.whl.metadata (4.8 kB)
#       Requirement already satisfied: Jinja2<4.0.0,>=3.0 in /opt/conda/lib/python3.11/site-packages (from conan) (3.1.4)
#       Requirement already satisfied: python-dateutil<3,>=2.8.0 in /opt/conda/lib/python3.11/site-packages (from conan) (2.9.0)
#       Requirement already satisfied: distro<2.0.0,>=1.4.0 in /opt/conda/lib/python3.11/site-packages (from conan) (1.9.0)
#       Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from Jinja2<4.0.0,>=3.0->conan) (2.1.5)
#       Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil<3,>=2.8.0->conan) (1.16.0)
#       Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.25->conan) (3.3.2)
#       Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.25->conan) (3.7)
#       Requirement already satisfied: certifi>=2023.5.7 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.25->conan) (2026.2.25)
#       Using cached conan-2.28.1-py3-none-any.whl (716 kB)
#       Using cached fasteners-0.20-py3-none-any.whl (18 kB)
#       Using cached patch_ng-1.19.1-py3-none-any.whl (17 kB)
#       Using cached urllib3-2.7.0-py3-none-any.whl (131 kB)
#       Installing collected packages: urllib3, patch-ng, fasteners, conan
#         Attempting uninstall: urllib3
#           Found existing installation: urllib3 1.25.11
#           Uninstalling urllib3-1.25.11:
#             Successfully uninstalled urllib3-1.25.11
#       Successfully installed conan-2.28.1 fasteners-0.20 patch-ng-1.19.1 urllib3-2.7.0
#       Traceback (most recent call last):
#         File "/tmp/pip-install-jz_3rie7/qiskit-aer_c5bd2157418546888fa18d0fa55c0195/setup.py", line 27, in <module>
#           from conans import client
#       ModuleNotFoundError: No module named 'conans'
#
#       During handling of the above exception, another exception occurred:
#
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/tmp/pip-install-jz_3rie7/qiskit-aer_c5bd2157418546888fa18d0fa55c0195/setup.py", line 33, in <module>
#           from conans import client
#       ImportError: cannot import name 'client' from 'conans' (/opt/conda/lib/python3.11/site-packages/conans/__init__.py)
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# !pip3 install qiskit_ibm_provider && pip3 install utils && pip3 install bitarray && pip3 install pandas && pip3 install tolist
# Out:
# Collecting qiskit_ibm_provider
#   Using cached qiskit_ibm_provider-0.11.0-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: qiskit>=0.45.0 in /opt/conda/lib/python3.11/site-packages (from qiskit_ibm_provider) (2.3.1)
# Requirement already satisfied: requests>=2.19 in /opt/conda/lib/python3.11/site-packages (from qiskit_ibm_provider) (2.33.1)
# Requirement already satisfied: requests-ntlm>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from qiskit_ibm_provider) (1.3.0)
# Requirement already satisfied: numpy>=1.13 in /opt/conda/lib/python3.11/site-packages (from qiskit_ibm_provider) (1.26.4)
# Requirement already satisfied: urllib3>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from qiskit_ibm_provider) (2.7.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /opt/conda/lib/python3.11/site-packages (from qiskit_ibm_provider) (2.9.0)
# Requirement already satisfied: websocket-client>=1.5.1 in /opt/conda/lib/python3.11/site-packages (from qiskit_ibm_provider) (1.8.0)
# Requirement already satisfied: websockets>=10.0 in /opt/conda/lib/python3.11/site-packages (from qiskit_ibm_provider) (16.0)
# Requirement already satisfied: typing-extensions>=4.3 in /opt/conda/lib/python3.11/site-packages (from qiskit_ibm_provider) (4.15.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.0->qiskit_ibm_provider) (1.16.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /opt/conda/lib/python3.11/site-packages (from qiskit>=0.45.0->qiskit_ibm_provider) (0.17.1)
# Requirement already satisfied: scipy>=1.5 in /opt/conda/lib/python3.11/site-packages (from qiskit>=0.45.0->qiskit_ibm_provider) (1.17.1)
# Requirement already satisfied: dill>=0.3 in /opt/conda/lib/python3.11/site-packages (from qiskit>=0.45.0->qiskit_ibm_provider) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/conda/lib/python3.11/site-packages (from qiskit>=0.45.0->qiskit_ibm_provider) (5.7.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.19->qiskit_ibm_provider) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests>=2.19->qiskit_ibm_provider) (3.7)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/conda/lib/python3.11/site-packages (from requests>=2.19->qiskit_ibm_provider) (2026.2.25)
# Requirement already satisfied: cryptography>=1.3 in /opt/conda/lib/python3.11/site-packages (from requests-ntlm>=1.1.0->qiskit_ibm_provider) (42.0.7)
# Requirement already satisfied: pyspnego>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from requests-ntlm>=1.1.0->qiskit_ibm_provider) (0.12.1)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.11/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit_ibm_provider) (1.16.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit_ibm_provider) (2.22)
# Using cached qiskit_ibm_provider-0.11.0-py3-none-any.whl (249 kB)
# Installing collected packages: qiskit_ibm_provider
# Successfully installed qiskit_ibm_provider-0.11.0
# Collecting utils
#   Using cached utils-1.0.2-py2.py3-none-any.whl
# Installing collected packages: utils
# Successfully installed utils-1.0.2
# Collecting bitarray
#   Using cached bitarray-3.8.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (34 kB)
# Using cached bitarray-3.8.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (339 kB)
# Installing collected packages: bitarray
# Successfully installed bitarray-3.8.1
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (3.0.1)
# Requirement already satisfied: numpy>=1.26.0 in /opt/conda/lib/python3.11/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (2.9.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Collecting tolist
#   Using cached tolist-0.0.post0.tar.gz (670 bytes)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [14 lines of output]
#       running egg_info
#       creating /tmp/pip-pip-egg-info-4j3ui22m/tolist.egg-info
#       writing /tmp/pip-pip-egg-info-4j3ui22m/tolist.egg-info/PKG-INFO
#       writing dependency_links to /tmp/pip-pip-egg-info-4j3ui22m/tolist.egg-info/dependency_links.txt
#       writing top-level names to /tmp/pip-pip-egg-info-4j3ui22m/tolist.egg-info/top_level.txt
#       writing manifest file '/tmp/pip-pip-egg-info-4j3ui22m/tolist.egg-info/SOURCES.txt'
#       reading manifest file '/tmp/pip-pip-egg-info-4j3ui22m/tolist.egg-info/SOURCES.txt'
#       writing manifest file '/tmp/pip-pip-egg-info-4j3ui22m/tolist.egg-info/SOURCES.txt'
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/tmp/pip-install-1mtut4u7/tolist_e452012d2c1542e2b6e8ac3cd1450765/setup.py", line 9, in <module>
#           raise RuntimeError("This is a dummy package that was never ment to be actually installed. Please contact platform(at)kiwi.com.")
#       RuntimeError: This is a dummy package that was never ment to be actually installed. Please contact platform(at)kiwi.com.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# !pip3 install qiskit-ibm-runtime --upgrades
# Out:
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# no such option: --upgrades

# %%
# !pip3 install \
  guppylang==0.20.* \
  selene-sim==0.2.12 \
  qnexus==0.20.0 --no-deps \
  pytket==2.15.* \
  pytket-quantinuum==0.18.* \
  ecdsa==0.19.* \
  numpy==2.2.6 \
  matplotlib==3.9.* \
  typing-extensions==4.12.*
# Out:
# Collecting guppylang==0.20.*
#   Using cached guppylang-0.20.0-py3-none-any.whl.metadata (15 kB)
# Collecting selene-sim==0.2.12
#   Using cached selene_sim-0.2.12-py3-none-manylinux_2_28_x86_64.whl.metadata (5.9 kB)
# Collecting qnexus==0.20.0
#   Using cached qnexus-0.20.0-py3-none-any.whl.metadata (14 kB)
# Collecting pytket==2.15.*
#   Using cached pytket-2.15.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.7 kB)
# Collecting pytket-quantinuum==0.18.*
#   Using cached pytket_quantinuum-0.18.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting ecdsa==0.19.*
#   Using cached ecdsa-0.19.2-py2.py3-none-any.whl.metadata (29 kB)
# Collecting numpy==2.2.6
#   Using cached numpy-2.2.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting matplotlib==3.9.*
#   Using cached matplotlib-3.9.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting typing-extensions==4.12.*
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Using cached guppylang-0.20.0-py3-none-any.whl (234 kB)
# Using cached selene_sim-0.2.12-py3-none-manylinux_2_28_x86_64.whl (4.4 MB)
# Using cached qnexus-0.20.0-py3-none-any.whl (60 kB)
# Using cached pytket-2.15.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (8.3 MB)
# Using cached pytket_quantinuum-0.18.0-py3-none-any.whl (31 kB)
# Using cached ecdsa-0.19.2-py2.py3-none-any.whl (150 kB)
# Using cached numpy-2.2.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
# Using cached matplotlib-3.9.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Installing collected packages: typing-extensions, selene-sim, qnexus, pytket-quantinuum, pytket, numpy, matplotlib, guppylang, ecdsa
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.15.0
#     Uninstalling typing_extensions-4.15.0:
#       Successfully uninstalled typing_extensions-4.15.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.8
#     Uninstalling matplotlib-3.10.8:
#       Successfully uninstalled matplotlib-3.10.8
# Successfully installed ecdsa-0.19.2 guppylang-0.20.0 matplotlib-3.9.4 numpy-2.2.6 pytket-2.15.0 pytket-quantinuum-0.18.0 qnexus-0.20.0 selene-sim-0.2.12 typing-extensions-4.12.2

# %%
# !pip3 install base58 && pip3 install parameters && pip3 install Crypto && pip3 install pycryptodome && pip3 install Cryptography && pip3 install bitcoin && pip3 install ecdsa && pip3 install bitcoin
# Out:
# Collecting base58
#   Using cached base58-2.1.1-py3-none-any.whl.metadata (3.1 kB)
# Using cached base58-2.1.1-py3-none-any.whl (5.6 kB)
# Installing collected packages: base58
# Successfully installed base58-2.1.1
# Collecting parameters
#   Using cached parameters-0.2.1-py3-none-any.whl
# Installing collected packages: parameters
# Successfully installed parameters-0.2.1
# Collecting Crypto
#   Using cached crypto-1.4.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Collecting Naked (from Crypto)
#   Using cached Naked-0.1.32-py2.py3-none-any.whl.metadata (931 bytes)
# Collecting shellescape (from Crypto)
#   Using cached shellescape-3.8.1-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from Naked->Crypto) (2.33.1)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.11/site-packages (from Naked->Crypto) (6.0.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->Naked->Crypto) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->Naked->Crypto) (3.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/conda/lib/python3.11/site-packages (from requests->Naked->Crypto) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/conda/lib/python3.11/site-packages (from requests->Naked->Crypto) (2026.2.25)
# Using cached crypto-1.4.1-py2.py3-none-any.whl (18 kB)
# Using cached Naked-0.1.32-py2.py3-none-any.whl (587 kB)
# Using cached shellescape-3.8.1-py2.py3-none-any.whl (3.1 kB)
# Installing collected packages: shellescape, Naked, Crypto
# Successfully installed Crypto-1.4.1 Naked-0.1.32 shellescape-3.8.1
# Collecting pycryptodome
#   Using cached pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Using cached pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
# Installing collected packages: pycryptodome
# Successfully installed pycryptodome-3.23.0
# Requirement already satisfied: Cryptography in /opt/conda/lib/python3.11/site-packages (42.0.7)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.11/site-packages (from Cryptography) (1.16.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.11/site-packages (from cffi>=1.12->Cryptography) (2.22)
# Collecting bitcoin
#   Using cached bitcoin-1.1.42-py3-none-any.whl
# Installing collected packages: bitcoin
# Successfully installed bitcoin-1.1.42
# Requirement already satisfied: ecdsa in /opt/conda/lib/python3.11/site-packages (0.19.2)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/lib/python3.11/site-packages (from ecdsa) (1.16.0)
# Requirement already satisfied: bitcoin in /opt/conda/lib/python3.11/site-packages (1.1.42)

# %%
# !pip3 install bit && pip3 install ice && pip3 install argparse && pip3 install pub && pip3 install requests && pip3 install ctypes
# Out:
# Collecting bit
#   Using cached bit-0.8.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting coincurve>=4.3.0 (from bit)
#   Using cached coincurve-21.0.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from bit) (2.33.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->bit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->bit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/conda/lib/python3.11/site-packages (from requests->bit) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/conda/lib/python3.11/site-packages (from requests->bit) (2026.2.25)
# Using cached bit-0.8.0-py3-none-any.whl (68 kB)
# Using cached coincurve-21.0.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
# Installing collected packages: coincurve, bit
# Successfully installed bit-0.8.0 coincurve-21.0.0
# Collecting ice
#   Using cached ice-0.0.2-py3-none-any.whl
# Installing collected packages: ice
# Successfully installed ice-0.0.2
# Collecting argparse
#   Using cached argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Installing collected packages: argparse
# Successfully installed argparse-1.4.0
# Collecting pub
#   Using cached pub-0.0.4-py3-none-any.whl
# Collecting path.py>=2.2 (from pub)
#   Using cached path.py-12.5.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting envoy>=0.0.2 (from pub)
#   Using cached envoy-0.0.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: networkx>=1.6 in /opt/conda/lib/python3.11/site-packages (from pub) (3.6.1)
# Collecting path (from path.py>=2.2->pub)
#   Using cached path-17.1.1-py3-none-any.whl.metadata (6.5 kB)
# Using cached envoy-0.0.3-py2.py3-none-any.whl (5.0 kB)
# Using cached path.py-12.5.0-py3-none-any.whl (2.3 kB)
# Using cached path-17.1.1-py3-none-any.whl (23 kB)
# Installing collected packages: envoy, path, path.py, pub
# Successfully installed envoy-0.0.3 path-17.1.1 path.py-12.5.0 pub-0.0.4
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (2.33.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/conda/lib/python3.11/site-packages (from requests) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/conda/lib/python3.11/site-packages (from requests) (2026.2.25)
# ERROR: Could not find a version that satisfies the requirement ctypes (from versions: none)
# ERROR: No matching distribution found for ctypes

# %%
# !pip3 install qiskit.algorithms && pip3 install qiskit-algorithms
# Out:
# Collecting qiskit.algorithms
#   Using cached qiskit_algorithms-0.4.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: qiskit>=1.0 in /opt/conda/lib/python3.11/site-packages (from qiskit.algorithms) (2.3.1)
# Requirement already satisfied: scipy>=1.4 in /opt/conda/lib/python3.11/site-packages (from qiskit.algorithms) (1.17.1)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.11/site-packages (from qiskit.algorithms) (2.2.6)
# Requirement already satisfied: rustworkx>=0.15.0 in /opt/conda/lib/python3.11/site-packages (from qiskit>=1.0->qiskit.algorithms) (0.17.1)
# Requirement already satisfied: dill>=0.3 in /opt/conda/lib/python3.11/site-packages (from qiskit>=1.0->qiskit.algorithms) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/conda/lib/python3.11/site-packages (from qiskit>=1.0->qiskit.algorithms) (5.7.0)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.11/site-packages (from qiskit>=1.0->qiskit.algorithms) (4.12.2)
# Using cached qiskit_algorithms-0.4.0-py3-none-any.whl (327 kB)
# Installing collected packages: qiskit.algorithms
# Successfully installed qiskit.algorithms-0.4.0
# Requirement already satisfied: qiskit-algorithms in /opt/conda/lib/python3.11/site-packages (0.4.0)
# Requirement already satisfied: qiskit>=1.0 in /opt/conda/lib/python3.11/site-packages (from qiskit-algorithms) (2.3.1)
# Requirement already satisfied: scipy>=1.4 in /opt/conda/lib/python3.11/site-packages (from qiskit-algorithms) (1.17.1)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.11/site-packages (from qiskit-algorithms) (2.2.6)
# Requirement already satisfied: rustworkx>=0.15.0 in /opt/conda/lib/python3.11/site-packages (from qiskit>=1.0->qiskit-algorithms) (0.17.1)
# Requirement already satisfied: dill>=0.3 in /opt/conda/lib/python3.11/site-packages (from qiskit>=1.0->qiskit-algorithms) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/conda/lib/python3.11/site-packages (from qiskit>=1.0->qiskit-algorithms) (5.7.0)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.11/site-packages (from qiskit>=1.0->qiskit-algorithms) (4.12.2)

# %%
# !pip3 install qiskit-Aer
# Out:
# Collecting qiskit-Aer
#   Using cached qiskit_aer-0.17.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.3 kB)
# Requirement already satisfied: qiskit>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from qiskit-Aer) (2.3.1)
# Requirement already satisfied: numpy>=1.16.3 in /opt/conda/lib/python3.11/site-packages (from qiskit-Aer) (2.2.6)
# Requirement already satisfied: scipy>=1.0 in /opt/conda/lib/python3.11/site-packages (from qiskit-Aer) (1.17.1)
# Requirement already satisfied: psutil>=5 in /opt/conda/lib/python3.11/site-packages (from qiskit-Aer) (5.9.8)
# Requirement already satisfied: python-dateutil>=2.8.0 in /opt/conda/lib/python3.11/site-packages (from qiskit-Aer) (2.9.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.0->qiskit-Aer) (1.16.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /opt/conda/lib/python3.11/site-packages (from qiskit>=1.1.0->qiskit-Aer) (0.17.1)
# Requirement already satisfied: dill>=0.3 in /opt/conda/lib/python3.11/site-packages (from qiskit>=1.1.0->qiskit-Aer) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/conda/lib/python3.11/site-packages (from qiskit>=1.1.0->qiskit-Aer) (5.7.0)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.11/site-packages (from qiskit>=1.1.0->qiskit-Aer) (4.12.2)
# Using cached qiskit_aer-0.17.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
# Installing collected packages: qiskit-Aer
# Successfully installed qiskit-Aer-0.17.2

# %%
# !pip3 install -U qiskit
# Out:
# Requirement already satisfied: qiskit in /opt/conda/lib/python3.11/site-packages (2.3.1)
# Collecting qiskit
#   Using cached qiskit-2.4.1-cp310-abi3-manylinux_2_28_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: rustworkx>=0.15.0 in /opt/conda/lib/python3.11/site-packages (from qiskit) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.21 in /opt/conda/lib/python3.11/site-packages (from qiskit) (2.2.6)
# Requirement already satisfied: scipy>=1.5 in /opt/conda/lib/python3.11/site-packages (from qiskit) (1.17.1)
# Requirement already satisfied: dill>=0.3 in /opt/conda/lib/python3.11/site-packages (from qiskit) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/conda/lib/python3.11/site-packages (from qiskit) (5.7.0)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.11/site-packages (from qiskit) (4.12.2)
# Using cached qiskit-2.4.1-cp310-abi3-manylinux_2_28_x86_64.whl (9.3 MB)
# Installing collected packages: qiskit
#   Attempting uninstall: qiskit
#     Found existing installation: qiskit 2.3.1
#     Uninstalling qiskit-2.3.1:
#       Successfully uninstalled qiskit-2.3.1
# Successfully installed qiskit-2.4.1

# %%
# !pip3 install httpx && pip3 install pylatexenc && pip3 install nest_asyncio && pip3 install pydantic_settings && pip3 install rich
# Out:
# Collecting pylatexenc
#   Using cached pylatexenc-2.10-py3-none-any.whl
# Installing collected packages: pylatexenc
# Successfully installed pylatexenc-2.10

# %%
# !pip3 install qiskit_utils
# Out:
# Collecting qiskit_utils
#   Using cached qiskit_utils-1.2.1-py3-none-any.whl
# Requirement already satisfied: qiskit>=0.34.2 in /opt/conda/lib/python3.11/site-packages (from qiskit_utils) (2.4.1)
# Requirement already satisfied: rustworkx>=0.15.0 in /opt/conda/lib/python3.11/site-packages (from qiskit>=0.34.2->qiskit_utils) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.21 in /opt/conda/lib/python3.11/site-packages (from qiskit>=0.34.2->qiskit_utils) (2.2.6)
# Requirement already satisfied: scipy>=1.5 in /opt/conda/lib/python3.11/site-packages (from qiskit>=0.34.2->qiskit_utils) (1.17.1)
# Requirement already satisfied: dill>=0.3 in /opt/conda/lib/python3.11/site-packages (from qiskit>=0.34.2->qiskit_utils) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/conda/lib/python3.11/site-packages (from qiskit>=0.34.2->qiskit_utils) (5.7.0)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.11/site-packages (from qiskit>=0.34.2->qiskit_utils) (4.12.2)
# Installing collected packages: qiskit_utils
# Successfully installed qiskit_utils-1.2.1

# %%
# !pip3 install qiskit.utils
# Out:
# Requirement already satisfied: qiskit.utils in /opt/conda/lib/python3.11/site-packages (1.2.1)
# Requirement already satisfied: qiskit>=0.34.2 in /opt/conda/lib/python3.11/site-packages (from qiskit.utils) (2.4.1)
# Requirement already satisfied: rustworkx>=0.15.0 in /opt/conda/lib/python3.11/site-packages (from qiskit>=0.34.2->qiskit.utils) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.21 in /opt/conda/lib/python3.11/site-packages (from qiskit>=0.34.2->qiskit.utils) (2.2.6)
# Requirement already satisfied: scipy>=1.5 in /opt/conda/lib/python3.11/site-packages (from qiskit>=0.34.2->qiskit.utils) (1.17.1)
# Requirement already satisfied: dill>=0.3 in /opt/conda/lib/python3.11/site-packages (from qiskit>=0.34.2->qiskit.utils) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/conda/lib/python3.11/site-packages (from qiskit>=0.34.2->qiskit.utils) (5.7.0)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.11/site-packages (from qiskit>=0.34.2->qiskit.utils) (4.12.2)

# %%
# !pip3 install synthesis && pip3 install period
# Out:
# Collecting synthesis
#   Using cached synthesis-1.1061-py3-none-any.whl
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from synthesis) (69.5.1)
# Installing collected packages: synthesis
# Successfully installed synthesis-1.1061
# Collecting period
#   Using cached period-0.6.1.tar.gz (8.4 kB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [6 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/tmp/pip-install-cg62xzyb/period_77fec3f59c7a49ff9a32946c88e9e3af/setup.py", line 7, in <module>
#           from pip.req import parse_requirements
#       ModuleNotFoundError: No module named 'pip.req'
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# !pip3 install helios && pip3 install fpylll
# Out:
# Collecting helios
#   Using cached helios-0.3.0-py3-none-any.whl.metadata (5.4 kB)
# Using cached helios-0.3.0-py3-none-any.whl (29 kB)
# Installing collected packages: helios
# Successfully installed helios-0.3.0
# Collecting fpylll
#   Using cached fpylll-0.6.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Using cached fpylll-0.6.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (41.6 MB)
# Installing collected packages: fpylll
# Successfully installed fpylll-0.6.4

# %%
# !pip3 install tket2-exts~=0.6.0 && pip3 install graphviz<0.21 && pip3 install hugr~=0.11.5 && pip3 install selene-hugr-qis-compiler~=0.2.6 && pip3 install quantinuum-schemas<8.0,>=7.5.0 && pip3 install nest-asyncio2<2.0,>=1.6
# Out:
# Collecting tket2-exts~=0.6.0
#   Using cached tket2_exts-0.6.0-py3-none-any.whl.metadata (15 kB)
# Collecting hugr~=0.11.1 (from tket2-exts~=0.6.0)
#   Using cached hugr-0.11.5-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting graphviz>=0.20.3 (from hugr~=0.11.1->tket2-exts~=0.6.0)
#   Using cached graphviz-0.21-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic<2.12,>=2.8 (from hugr~=0.11.1->tket2-exts~=0.6.0)
#   Using cached pydantic-2.11.10-py3-none-any.whl.metadata (68 kB)
# Collecting pydantic-extra-types>=2.9.0 (from hugr~=0.11.1->tket2-exts~=0.6.0)
#   Using cached pydantic_extra_types-2.11.1-py3-none-any.whl.metadata (4.2 kB)
# Collecting semver>=3.0.2 (from hugr~=0.11.1->tket2-exts~=0.6.0)
#   Using cached semver-3.0.4-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: typing-extensions~=4.12 in /opt/conda/lib/python3.11/site-packages (from hugr~=0.11.1->tket2-exts~=0.6.0) (4.12.2)
# Collecting pyzstd~=0.16.2 (from hugr~=0.11.1->tket2-exts~=0.6.0)
#   Using cached pyzstd-0.16.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.4 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<2.12,>=2.8->hugr~=0.11.1->tket2-exts~=0.6.0) (0.7.0)
# Collecting pydantic-core==2.33.2 (from pydantic<2.12,>=2.8->hugr~=0.11.1->tket2-exts~=0.6.0)
#   Using cached pydantic_core-2.33.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<2.12,>=2.8->hugr~=0.11.1->tket2-exts~=0.6.0) (0.4.2)
# Using cached tket2_exts-0.6.0-py3-none-any.whl (17 kB)
# Using cached hugr-0.11.5-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (598 kB)
# Using cached graphviz-0.21-py3-none-any.whl (47 kB)
# Using cached pydantic-2.11.10-py3-none-any.whl (444 kB)
# Using cached pydantic_core-2.33.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
# Using cached pydantic_extra_types-2.11.1-py3-none-any.whl (79 kB)
# Using cached pyzstd-0.16.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (413 kB)
# Using cached semver-3.0.4-py3-none-any.whl (17 kB)
# Installing collected packages: semver, pyzstd, pydantic-core, graphviz, pydantic, pydantic-extra-types, hugr, tket2-exts
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.41.5
#     Uninstalling pydantic_core-2.41.5:
#       Successfully uninstalled pydantic_core-2.41.5
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.12.5
#     Uninstalling pydantic-2.12.5:
#       Successfully uninstalled pydantic-2.12.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytket 2.15.0 requires lark>=1.1.9, which is not installed.
# pytket 2.15.0 requires qwasm>=1.0.1, which is not installed.
# qnexus 0.20.0 requires quantinuum-schemas<4.0,>=3.2.3, which is not installed.
# qnexus 0.20.0 requires pandas<3,>=2, but you have pandas 3.0.1 which is incompatible.
# qnexus 0.20.0 requires rich<14.0,>=13.6, but you have rich 14.3.3 which is incompatible.
# qnexus 0.20.0 requires websockets<14,>11, but you have websockets 16.0 which is incompatible.
# guppylang 0.20.0 requires graphviz<0.21,>=0.20.1, but you have graphviz 0.21 which is incompatible.
# guppylang 0.20.0 requires hugr~=0.12.1, but you have hugr 0.11.5 which is incompatible.
# guppylang 0.20.0 requires tket2-exts~=0.9.1, but you have tket2-exts 0.6.0 which is incompatible.
# qbraid 0.11.2.dev20260303161736 requires qbraid-core<0.3.0,>=0.2.0, but you have qbraid-core 0.2.0a9 which is incompatible.
# Successfully installed graphviz-0.21 hugr-0.11.5 pydantic-2.11.10 pydantic-core-2.33.2 pydantic-extra-types-2.11.1 pyzstd-0.16.2 semver-3.0.4 tket2-exts-0.6.0
# /bin/bash: line 1: 0.21: No such file or directory

# %%
# !pip3 install qwasm && pip3 install quantinuum_schemas
# Out:
# Collecting qwasm
#   Using cached qwasm-1.0.1-py3-none-any.whl.metadata (299 bytes)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from qwasm) (69.5.1)
# Using cached qwasm-1.0.1-py3-none-any.whl (15 kB)
# Installing collected packages: qwasm
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytket 2.15.0 requires lark>=1.1.9, which is not installed.
# qnexus 0.20.0 requires quantinuum-schemas<4.0,>=3.2.3, which is not installed.
# qnexus 0.20.0 requires pandas<3,>=2, but you have pandas 3.0.1 which is incompatible.
# qnexus 0.20.0 requires rich<14.0,>=13.6, but you have rich 14.3.3 which is incompatible.
# qnexus 0.20.0 requires websockets<14,>11, but you have websockets 16.0 which is incompatible.
# Successfully installed qwasm-1.0.1
# Collecting quantinuum_schemas
#   Using cached quantinuum_schemas-7.7.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: orjson<4.0.0,>=3.10.18 in /opt/conda/lib/python3.11/site-packages (from quantinuum_schemas) (3.11.9)
# Requirement already satisfied: pydantic-extra-types<3.0.0,>=2.10.5 in /opt/conda/lib/python3.11/site-packages (from quantinuum_schemas) (2.11.1)
# Requirement already satisfied: pydantic<3,>=2.6.0 in /opt/conda/lib/python3.11/site-packages (from quantinuum_schemas) (2.11.10)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<3,>=2.6.0->quantinuum_schemas) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/conda/lib/python3.11/site-packages (from pydantic<3,>=2.6.0->quantinuum_schemas) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /opt/conda/lib/python3.11/site-packages (from pydantic<3,>=2.6.0->quantinuum_schemas) (4.12.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<3,>=2.6.0->quantinuum_schemas) (0.4.2)
# Using cached quantinuum_schemas-7.7.1-py3-none-any.whl (26 kB)
# Installing collected packages: quantinuum_schemas
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# qnexus 0.20.0 requires pandas<3,>=2, but you have pandas 3.0.1 which is incompatible.
# qnexus 0.20.0 requires quantinuum-schemas<4.0,>=3.2.3, but you have quantinuum-schemas 7.7.1 which is incompatible.
# qnexus 0.20.0 requires rich<14.0,>=13.6, but you have rich 14.3.3 which is incompatible.
# qnexus 0.20.0 requires websockets<14,>11, but you have websockets 16.0 which is incompatible.
# Successfully installed quantinuum_schemas-7.7.1

# %%
# !pip3 install pyyaml && pip3 install selene-core && pip3 install selene-hugr-qis-compiler && pip3 install tqdm && pip3 install msal~=1.18 && pip3 install types-requests && pip3 install pytket~=1.17 && pip3 install quantinuum-schemas<4.0,>=3.2.3 && pip3 install websockets<14,>11 && pip3 install pydantic<3.0.0,>=2.12.0
# Out:
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.11/site-packages (6.0.1)
# Collecting selene-core
#   Using cached selene_core-0.2.9-py3-none-any.whl.metadata (2.0 kB)
# Collecting hugr>=0.13.0 (from selene-core)
#   Using cached hugr-0.16.0-cp310-abi3-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting lief>=0.16.5 (from selene-core)
#   Using cached lief-0.17.6-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (2.4 kB)
# Collecting llvmlite~=0.47 (from selene-core)
#   Using cached llvmlite-0.47.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: networkx<4,>=2.6 in /opt/conda/lib/python3.11/site-packages (from selene-core) (3.6.1)
# Collecting pydantic>=2.12.5 (from selene-core)
#   Using cached pydantic-2.13.4-py3-none-any.whl.metadata (109 kB)
# Collecting pydot>=4.0.0 (from selene-core)
#   Using cached pydot-4.0.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pyyaml~=6.0 in /opt/conda/lib/python3.11/site-packages (from selene-core) (6.0.1)
# Requirement already satisfied: typing-extensions>=4 in /opt/conda/lib/python3.11/site-packages (from selene-core) (4.12.2)
# Collecting ziglang~=0.13 (from selene-core)
#   Using cached ziglang-0.16.0-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.musllinux_1_1_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: graphviz>=0.20.3 in /opt/conda/lib/python3.11/site-packages (from hugr>=0.13.0->selene-core) (0.21)
# Requirement already satisfied: pydantic-extra-types~=2.9 in /opt/conda/lib/python3.11/site-packages (from hugr>=0.13.0->selene-core) (2.11.1)
# Requirement already satisfied: semver~=3.0 in /opt/conda/lib/python3.11/site-packages (from hugr>=0.13.0->selene-core) (3.0.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from pydantic>=2.12.5->selene-core) (0.7.0)
# Collecting pydantic-core==2.46.4 (from pydantic>=2.12.5->selene-core)
#   Using cached pydantic_core-2.46.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting typing-extensions>=4 (from selene-core)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/conda/lib/python3.11/site-packages (from pydantic>=2.12.5->selene-core) (0.4.2)
# Requirement already satisfied: pyparsing>=3.1.0 in /opt/conda/lib/python3.11/site-packages (from pydot>=4.0.0->selene-core) (3.3.2)
# Using cached selene_core-0.2.9-py3-none-any.whl (33 kB)
# Using cached hugr-0.16.0-cp310-abi3-manylinux_2_28_x86_64.whl (3.7 MB)
# Using cached lief-0.17.6-cp311-cp311-manylinux_2_28_x86_64.whl (3.4 MB)
# Using cached llvmlite-0.47.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
# Using cached pydantic-2.13.4-py3-none-any.whl (472 kB)
# Using cached pydantic_core-2.46.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
# Using cached pydot-4.0.1-py3-none-any.whl (37 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached ziglang-0.16.0-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.musllinux_1_1_x86_64.whl (97.9 MB)
# Installing collected packages: ziglang, typing-extensions, pydot, llvmlite, lief, pydantic-core, pydantic, hugr, selene-core
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.33.2
#     Uninstalling pydantic_core-2.33.2:
#       Successfully uninstalled pydantic_core-2.33.2
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.11.10
#     Uninstalling pydantic-2.11.10:
#       Successfully uninstalled pydantic-2.11.10
#   Attempting uninstall: hugr
#     Found existing installation: hugr 0.11.5
#     Uninstalling hugr-0.11.5:
#       Successfully uninstalled hugr-0.11.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# selene-sim 0.2.12 requires selene-hugr-qis-compiler~=0.2.6, which is not installed.
# pytket 2.15.0 requires lark>=1.1.9, which is not installed.
# tket2-exts 0.6.0 requires hugr~=0.11.1, but you have hugr 0.16.0 which is incompatible.
# selene-sim 0.2.12 requires pyyaml>=6.0.2, but you have pyyaml 6.0.1 which is incompatible.
# selene-sim 0.2.12 requires tqdm>=4.67.1, but you have tqdm 4.66.4 which is incompatible.
# qnexus 0.20.0 requires pandas<3,>=2, but you have pandas 3.0.1 which is incompatible.
# qnexus 0.20.0 requires quantinuum-schemas<4.0,>=3.2.3, but you have quantinuum-schemas 7.7.1 which is incompatible.
# qnexus 0.20.0 requires rich<14.0,>=13.6, but you have rich 14.3.3 which is incompatible.
# qnexus 0.20.0 requires websockets<14,>11, but you have websockets 16.0 which is incompatible.
# guppylang 0.20.0 requires graphviz<0.21,>=0.20.1, but you have graphviz 0.21 which is incompatible.
# guppylang 0.20.0 requires hugr~=0.12.1, but you have hugr 0.16.0 which is incompatible.
# guppylang 0.20.0 requires tket2-exts~=0.9.1, but you have tket2-exts 0.6.0 which is incompatible.
# qbraid 0.11.2.dev20260303161736 requires qbraid-core<0.3.0,>=0.2.0, but you have qbraid-core 0.2.0a9 which is incompatible.
# cirq-core 1.4.1 requires numpy~=1.22, but you have numpy 2.2.6 which is incompatible.
# Successfully installed hugr-0.16.0 lief-0.17.6 llvmlite-0.47.0 pydantic-2.13.4 pydantic-core-2.46.4 pydot-4.0.1 selene-core-0.2.9 typing-extensions-4.15.0 ziglang-0.16.0
# Collecting selene-hugr-qis-compiler
#   Using cached selene_hugr_qis_compiler-0.2.10-cp310-abi3-manylinux_2_28_x86_64.whl.metadata (2.2 kB)
# Using cached selene_hugr_qis_compiler-0.2.10-cp310-abi3-manylinux_2_28_x86_64.whl (34.0 MB)
# Installing collected packages: selene-hugr-qis-compiler
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# selene-sim 0.2.12 requires pyyaml>=6.0.2, but you have pyyaml 6.0.1 which is incompatible.
# selene-sim 0.2.12 requires tqdm>=4.67.1, but you have tqdm 4.66.4 which is incompatible.
# Successfully installed selene-hugr-qis-compiler-0.2.10
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.11/site-packages (4.66.4)
# Requirement already satisfied: msal~=1.18 in /opt/conda/lib/python3.11/site-packages (1.35.1)
# Requirement already satisfied: requests<3,>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from msal~=1.18) (2.33.1)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal~=1.18) (2.12.1)
# Requirement already satisfied: cryptography<49,>=2.5 in /opt/conda/lib/python3.11/site-packages (from msal~=1.18) (42.0.7)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.11/site-packages (from cryptography<49,>=2.5->msal~=1.18) (1.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.0.0->msal~=1.18) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.0.0->msal~=1.18) (3.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.0.0->msal~=1.18) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.0.0->msal~=1.18) (2026.2.25)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.11/site-packages (from cffi>=1.12->cryptography<49,>=2.5->msal~=1.18) (2.22)
# Collecting types-requests
#   Using cached types_requests-2.33.0.20260508-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: urllib3>=2 in /opt/conda/lib/python3.11/site-packages (from types-requests) (2.7.0)
# Using cached types_requests-2.33.0.20260508-py3-none-any.whl (20 kB)
# Installing collected packages: types-requests
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytket-quantinuum 0.18.0 requires pytket~=1.17, but you have pytket 2.15.0 which is incompatible.
# Successfully installed types-requests-2.33.0.20260508
# Collecting pytket~=1.17
#   Using cached pytket-1.41.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.7 kB)
# Requirement already satisfied: sympy>=1.12.1 in /opt/conda/lib/python3.11/site-packages (from pytket~=1.17) (1.14.0)
# Requirement already satisfied: numpy>=1.26.4 in /opt/conda/lib/python3.11/site-packages (from pytket~=1.17) (2.2.6)
# Collecting lark>=1.1.9 (from pytket~=1.17)
#   Using cached lark-1.3.1-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: scipy>=1.13.1 in /opt/conda/lib/python3.11/site-packages (from pytket~=1.17) (1.17.1)
# Requirement already satisfied: networkx>=2.8.8 in /opt/conda/lib/python3.11/site-packages (from pytket~=1.17) (3.6.1)
# Requirement already satisfied: graphviz>=0.20.3 in /opt/conda/lib/python3.11/site-packages (from pytket~=1.17) (0.21)
# Requirement already satisfied: jinja2>=3.1.4 in /opt/conda/lib/python3.11/site-packages (from pytket~=1.17) (3.1.4)
# Requirement already satisfied: typing-extensions>=4.12.2 in /opt/conda/lib/python3.11/site-packages (from pytket~=1.17) (4.15.0)
# Requirement already satisfied: qwasm>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from pytket~=1.17) (1.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2>=3.1.4->pytket~=1.17) (2.1.5)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from qwasm>=1.0.1->pytket~=1.17) (69.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from sympy>=1.12.1->pytket~=1.17) (1.3.0)
# Using cached pytket-1.41.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (8.4 MB)
# Using cached lark-1.3.1-py3-none-any.whl (113 kB)
# Installing collected packages: lark, pytket
#   Attempting uninstall: pytket
#     Found existing installation: pytket 2.15.0
#     Uninstalling pytket-2.15.0:
#       Successfully uninstalled pytket-2.15.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# qnexus 0.20.0 requires pandas<3,>=2, but you have pandas 3.0.1 which is incompatible.
# qnexus 0.20.0 requires pytket<3.0,>=2.3.1, but you have pytket 1.41.0 which is incompatible.
# qnexus 0.20.0 requires quantinuum-schemas<4.0,>=3.2.3, but you have quantinuum-schemas 7.7.1 which is incompatible.
# qnexus 0.20.0 requires rich<14.0,>=13.6, but you have rich 14.3.3 which is incompatible.
# qnexus 0.20.0 requires websockets<14,>11, but you have websockets 16.0 which is incompatible.
# Successfully installed lark-1.3.1 pytket-1.41.0
# /bin/bash: line 1: 4.0,: No such file or directory

# %%
# !pip3 show selene-sim
# Out:
# Name: selene-sim
# Version: 0.2.12
# Summary: Quantinuum's open source emulator for hybrid quantum computation
# Home-page:
# Author:
# Author-email: Jake Arkinstall <jake.arkinstall@quantinuum.com>, TKET development team <tket-support@quantinuum.com>
# License:
# Location: /opt/conda/lib/python3.11/site-packages
# Requires: numpy, pyyaml, selene-core, selene-hugr-qis-compiler, tqdm
# Required-by:

# %%
import selene_sim
print(dir(selene_sim))  # list all exported names
# Out:
# ['BitcodeString', 'BuildMethod', 'CircuitExtractor', 'ClassicalReplay', 'Coinflip', 'DepolarizingErrorModel', 'EventHook', 'HeliosInterface', 'IdealErrorModel', 'MeasurementExtractor', 'MetricStore', 'MultiEventHook', 'NoEventHook', 'QuantumReplay', 'Quest', 'SeleneInstance', 'SimpleLeakageErrorModel', 'SimpleRuntime', 'SoftRZRuntime', 'Stim', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', 'backends', 'build', 'dist_dir', 'event_hooks', 'exceptions', 'instance', 'pathlib', 'process', 'result_handling', 'timeout']

# %%
# !pip3 install tket2-exts~=0.8.0 && pip3 install graphviz~=0.20.1 && pip3 install hugr~=0.13.1 && pip3 install selene-hugr-qis-compiler~=0.2.6 && pip3 install quantinuum-schemas<4.0,>=3.2.3 && pip3 install websockets<14,>11 && pip3 install nest-asyncio2
# Out:
# Collecting tket2-exts~=0.8.0
#   Using cached tket2_exts-0.8.0-py3-none-any.whl.metadata (15 kB)
# Collecting hugr~=0.12.0 (from tket2-exts~=0.8.0)
#   Using cached hugr-0.12.5-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: graphviz>=0.20.3 in /opt/conda/lib/python3.11/site-packages (from hugr~=0.12.0->tket2-exts~=0.8.0) (0.21)
# Collecting pydantic<2.12,>=2.8 (from hugr~=0.12.0->tket2-exts~=0.8.0)
#   Using cached pydantic-2.11.10-py3-none-any.whl.metadata (68 kB)
# Requirement already satisfied: pydantic-extra-types>=2.9.0 in /opt/conda/lib/python3.11/site-packages (from hugr~=0.12.0->tket2-exts~=0.8.0) (2.11.1)
# Requirement already satisfied: semver>=3.0.2 in /opt/conda/lib/python3.11/site-packages (from hugr~=0.12.0->tket2-exts~=0.8.0) (3.0.4)
# Requirement already satisfied: typing-extensions~=4.12 in /opt/conda/lib/python3.11/site-packages (from hugr~=0.12.0->tket2-exts~=0.8.0) (4.15.0)
# Requirement already satisfied: pyzstd<0.18.0,>=0.16.2 in /opt/conda/lib/python3.11/site-packages (from hugr~=0.12.0->tket2-exts~=0.8.0) (0.16.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<2.12,>=2.8->hugr~=0.12.0->tket2-exts~=0.8.0) (0.7.0)
# Collecting pydantic-core==2.33.2 (from pydantic<2.12,>=2.8->hugr~=0.12.0->tket2-exts~=0.8.0)
#   Using cached pydantic_core-2.33.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<2.12,>=2.8->hugr~=0.12.0->tket2-exts~=0.8.0) (0.4.2)
# Using cached tket2_exts-0.8.0-py3-none-any.whl (18 kB)
# Using cached hugr-0.12.5-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (603 kB)
# Using cached pydantic-2.11.10-py3-none-any.whl (444 kB)
# Using cached pydantic_core-2.33.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
# Installing collected packages: pydantic-core, pydantic, hugr, tket2-exts
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.46.4
#     Uninstalling pydantic_core-2.46.4:
#       Successfully uninstalled pydantic_core-2.46.4
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.13.4
#     Uninstalling pydantic-2.13.4:
#       Successfully uninstalled pydantic-2.13.4
#   Attempting uninstall: hugr
#     Found existing installation: hugr 0.16.0
#     Uninstalling hugr-0.16.0:
#       Successfully uninstalled hugr-0.16.0
#   Attempting uninstall: tket2-exts
#     Found existing installation: tket2-exts 0.6.0
#     Uninstalling tket2-exts-0.6.0:
#       Successfully uninstalled tket2-exts-0.6.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# selene-core 0.2.9 requires hugr>=0.13.0, but you have hugr 0.12.5 which is incompatible.
# selene-core 0.2.9 requires pydantic>=2.12.5, but you have pydantic 2.11.10 which is incompatible.
# selene-sim 0.2.12 requires pyyaml>=6.0.2, but you have pyyaml 6.0.1 which is incompatible.
# selene-sim 0.2.12 requires tqdm>=4.67.1, but you have tqdm 4.66.4 which is incompatible.
# qnexus 0.20.0 requires pandas<3,>=2, but you have pandas 3.0.1 which is incompatible.
# qnexus 0.20.0 requires pytket<3.0,>=2.3.1, but you have pytket 1.41.0 which is incompatible.
# qnexus 0.20.0 requires quantinuum-schemas<4.0,>=3.2.3, but you have quantinuum-schemas 7.7.1 which is incompatible.
# qnexus 0.20.0 requires rich<14.0,>=13.6, but you have rich 14.3.3 which is incompatible.
# qnexus 0.20.0 requires websockets<14,>11, but you have websockets 16.0 which is incompatible.
# guppylang 0.20.0 requires graphviz<0.21,>=0.20.1, but you have graphviz 0.21 which is incompatible.
# guppylang 0.20.0 requires tket2-exts~=0.9.1, but you have tket2-exts 0.8.0 which is incompatible.
# qbraid 0.11.2.dev20260303161736 requires qbraid-core<0.3.0,>=0.2.0, but you have qbraid-core 0.2.0a9 which is incompatible.
# Successfully installed hugr-0.12.5 pydantic-2.11.10 pydantic-core-2.33.2 tket2-exts-0.8.0
# Collecting graphviz~=0.20.1
#   Using cached graphviz-0.20.3-py3-none-any.whl.metadata (12 kB)
# Using cached graphviz-0.20.3-py3-none-any.whl (47 kB)
# Installing collected packages: graphviz
#   Attempting uninstall: graphviz
#     Found existing installation: graphviz 0.21
#     Uninstalling graphviz-0.21:
#       Successfully uninstalled graphviz-0.21
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# qnexus 0.20.0 requires pandas<3,>=2, but you have pandas 3.0.1 which is incompatible.
# qnexus 0.20.0 requires pytket<3.0,>=2.3.1, but you have pytket 1.41.0 which is incompatible.
# qnexus 0.20.0 requires quantinuum-schemas<4.0,>=3.2.3, but you have quantinuum-schemas 7.7.1 which is incompatible.
# qnexus 0.20.0 requires rich<14.0,>=13.6, but you have rich 14.3.3 which is incompatible.
# qnexus 0.20.0 requires websockets<14,>11, but you have websockets 16.0 which is incompatible.
# guppylang 0.20.0 requires tket2-exts~=0.9.1, but you have tket2-exts 0.8.0 which is incompatible.
# Successfully installed graphviz-0.20.3
# Collecting hugr~=0.13.1
#   Using cached hugr-0.13.1-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: graphviz>=0.20.3 in /opt/conda/lib/python3.11/site-packages (from hugr~=0.13.1) (0.20.3)
# Requirement already satisfied: pydantic<2.12,>=2.8 in /opt/conda/lib/python3.11/site-packages (from hugr~=0.13.1) (2.11.10)
# Requirement already satisfied: pydantic-extra-types>=2.9.0 in /opt/conda/lib/python3.11/site-packages (from hugr~=0.13.1) (2.11.1)
# Requirement already satisfied: semver>=3.0.2 in /opt/conda/lib/python3.11/site-packages (from hugr~=0.13.1) (3.0.4)
# Requirement already satisfied: typing-extensions~=4.12 in /opt/conda/lib/python3.11/site-packages (from hugr~=0.13.1) (4.15.0)
# Requirement already satisfied: pyzstd<0.18.0,>=0.16.2 in /opt/conda/lib/python3.11/site-packages (from hugr~=0.13.1) (0.16.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<2.12,>=2.8->hugr~=0.13.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/conda/lib/python3.11/site-packages (from pydantic<2.12,>=2.8->hugr~=0.13.1) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<2.12,>=2.8->hugr~=0.13.1) (0.4.2)
# Using cached hugr-0.13.1-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (612 kB)
# Installing collected packages: hugr
#   Attempting uninstall: hugr
#     Found existing installation: hugr 0.12.5
#     Uninstalling hugr-0.12.5:
#       Successfully uninstalled hugr-0.12.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# selene-core 0.2.9 requires pydantic>=2.12.5, but you have pydantic 2.11.10 which is incompatible.
# selene-sim 0.2.12 requires pyyaml>=6.0.2, but you have pyyaml 6.0.1 which is incompatible.
# selene-sim 0.2.12 requires tqdm>=4.67.1, but you have tqdm 4.66.4 which is incompatible.
# tket2-exts 0.8.0 requires hugr~=0.12.0, but you have hugr 0.13.1 which is incompatible.
# qnexus 0.20.0 requires pandas<3,>=2, but you have pandas 3.0.1 which is incompatible.
# qnexus 0.20.0 requires pytket<3.0,>=2.3.1, but you have pytket 1.41.0 which is incompatible.
# qnexus 0.20.0 requires quantinuum-schemas<4.0,>=3.2.3, but you have quantinuum-schemas 7.7.1 which is incompatible.
# qnexus 0.20.0 requires rich<14.0,>=13.6, but you have rich 14.3.3 which is incompatible.
# qnexus 0.20.0 requires websockets<14,>11, but you have websockets 16.0 which is incompatible.
# guppylang 0.20.0 requires hugr~=0.12.1, but you have hugr 0.13.1 which is incompatible.
# guppylang 0.20.0 requires tket2-exts~=0.9.1, but you have tket2-exts 0.8.0 which is incompatible.
# Successfully installed hugr-0.13.1
# Requirement already satisfied: selene-hugr-qis-compiler~=0.2.6 in /opt/conda/lib/python3.11/site-packages (0.2.10)
# /bin/bash: line 1: 4.0,: No such file or directory

# %%
# !pip3 install tket2-exts~=0.8.0 && pip3 install quantinuum-schemas~=4.0 && pip3 install pytket~=2.3.1 && pip3 install tket2-exts~=0.9.1 && pip3 install quantinuum-schemas~=3.2.3 && pip3 install colorama
# Out:
# Requirement already satisfied: tket2-exts~=0.8.0 in /opt/conda/lib/python3.11/site-packages (0.8.0)
# Collecting hugr~=0.12.0 (from tket2-exts~=0.8.0)
#   Using cached hugr-0.12.5-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: graphviz>=0.20.3 in /opt/conda/lib/python3.11/site-packages (from hugr~=0.12.0->tket2-exts~=0.8.0) (0.20.3)
# Requirement already satisfied: pydantic<2.12,>=2.8 in /opt/conda/lib/python3.11/site-packages (from hugr~=0.12.0->tket2-exts~=0.8.0) (2.11.10)
# Requirement already satisfied: pydantic-extra-types>=2.9.0 in /opt/conda/lib/python3.11/site-packages (from hugr~=0.12.0->tket2-exts~=0.8.0) (2.11.1)
# Requirement already satisfied: semver>=3.0.2 in /opt/conda/lib/python3.11/site-packages (from hugr~=0.12.0->tket2-exts~=0.8.0) (3.0.4)
# Requirement already satisfied: typing-extensions~=4.12 in /opt/conda/lib/python3.11/site-packages (from hugr~=0.12.0->tket2-exts~=0.8.0) (4.15.0)
# Requirement already satisfied: pyzstd<0.18.0,>=0.16.2 in /opt/conda/lib/python3.11/site-packages (from hugr~=0.12.0->tket2-exts~=0.8.0) (0.16.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<2.12,>=2.8->hugr~=0.12.0->tket2-exts~=0.8.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/conda/lib/python3.11/site-packages (from pydantic<2.12,>=2.8->hugr~=0.12.0->tket2-exts~=0.8.0) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<2.12,>=2.8->hugr~=0.12.0->tket2-exts~=0.8.0) (0.4.2)
# Using cached hugr-0.12.5-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (603 kB)
# Installing collected packages: hugr
#   Attempting uninstall: hugr
#     Found existing installation: hugr 0.13.1
#     Uninstalling hugr-0.13.1:
#       Successfully uninstalled hugr-0.13.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# selene-core 0.2.9 requires hugr>=0.13.0, but you have hugr 0.12.5 which is incompatible.
# selene-core 0.2.9 requires pydantic>=2.12.5, but you have pydantic 2.11.10 which is incompatible.
# selene-sim 0.2.12 requires pyyaml>=6.0.2, but you have pyyaml 6.0.1 which is incompatible.
# selene-sim 0.2.12 requires tqdm>=4.67.1, but you have tqdm 4.66.4 which is incompatible.
# qnexus 0.20.0 requires pandas<3,>=2, but you have pandas 3.0.1 which is incompatible.
# qnexus 0.20.0 requires pytket<3.0,>=2.3.1, but you have pytket 1.41.0 which is incompatible.
# qnexus 0.20.0 requires quantinuum-schemas<4.0,>=3.2.3, but you have quantinuum-schemas 7.7.1 which is incompatible.
# qnexus 0.20.0 requires rich<14.0,>=13.6, but you have rich 14.3.3 which is incompatible.
# qnexus 0.20.0 requires websockets<14,>11, but you have websockets 16.0 which is incompatible.
# guppylang 0.20.0 requires tket2-exts~=0.9.1, but you have tket2-exts 0.8.0 which is incompatible.
# Successfully installed hugr-0.12.5
# Collecting quantinuum-schemas~=4.0
#   Using cached quantinuum_schemas-4.0.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: orjson<4.0.0,>=3.10.18 in /opt/conda/lib/python3.11/site-packages (from quantinuum-schemas~=4.0) (3.11.9)
# Requirement already satisfied: pydantic<3.0.0,>=2.6.0 in /opt/conda/lib/python3.11/site-packages (from quantinuum-schemas~=4.0) (2.11.10)
# Requirement already satisfied: pydantic-extra-types<3.0.0,>=2.10.5 in /opt/conda/lib/python3.11/site-packages (from quantinuum-schemas~=4.0) (2.11.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.6.0->quantinuum-schemas~=4.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/conda/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.6.0->quantinuum-schemas~=4.0) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /opt/conda/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.6.0->quantinuum-schemas~=4.0) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.6.0->quantinuum-schemas~=4.0) (0.4.2)
# Using cached quantinuum_schemas-4.0.0-py3-none-any.whl (15 kB)
# Installing collected packages: quantinuum-schemas
#   Attempting uninstall: quantinuum-schemas
#     Found existing installation: quantinuum-schemas 7.7.1
#     Uninstalling quantinuum-schemas-7.7.1:
#       Successfully uninstalled quantinuum-schemas-7.7.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# qnexus 0.20.0 requires pandas<3,>=2, but you have pandas 3.0.1 which is incompatible.
# qnexus 0.20.0 requires pytket<3.0,>=2.3.1, but you have pytket 1.41.0 which is incompatible.
# qnexus 0.20.0 requires quantinuum-schemas<4.0,>=3.2.3, but you have quantinuum-schemas 4.0.0 which is incompatible.
# qnexus 0.20.0 requires rich<14.0,>=13.6, but you have rich 14.3.3 which is incompatible.
# qnexus 0.20.0 requires websockets<14,>11, but you have websockets 16.0 which is incompatible.
# Successfully installed quantinuum-schemas-4.0.0
# Collecting pytket~=2.3.1
#   Using cached pytket-2.3.2-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.7 kB)
# Requirement already satisfied: sympy>=1.12.1 in /opt/conda/lib/python3.11/site-packages (from pytket~=2.3.1) (1.14.0)
# Requirement already satisfied: numpy>=1.26.4 in /opt/conda/lib/python3.11/site-packages (from pytket~=2.3.1) (2.2.6)
# Requirement already satisfied: lark>=1.1.9 in /opt/conda/lib/python3.11/site-packages (from pytket~=2.3.1) (1.3.1)
# Requirement already satisfied: scipy>=1.13.1 in /opt/conda/lib/python3.11/site-packages (from pytket~=2.3.1) (1.17.1)
# Requirement already satisfied: networkx>=2.8.8 in /opt/conda/lib/python3.11/site-packages (from pytket~=2.3.1) (3.6.1)
# Requirement already satisfied: graphviz>=0.20.3 in /opt/conda/lib/python3.11/site-packages (from pytket~=2.3.1) (0.20.3)
# Requirement already satisfied: jinja2>=3.1.4 in /opt/conda/lib/python3.11/site-packages (from pytket~=2.3.1) (3.1.4)
# Requirement already satisfied: typing-extensions>=4.12.2 in /opt/conda/lib/python3.11/site-packages (from pytket~=2.3.1) (4.15.0)
# Requirement already satisfied: qwasm>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from pytket~=2.3.1) (1.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2>=3.1.4->pytket~=2.3.1) (2.1.5)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from qwasm>=1.0.1->pytket~=2.3.1) (69.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from sympy>=1.12.1->pytket~=2.3.1) (1.3.0)
# Using cached pytket-2.3.2-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (8.2 MB)
# Installing collected packages: pytket
#   Attempting uninstall: pytket
#     Found existing installation: pytket 1.41.0
#     Uninstalling pytket-1.41.0:
#       Successfully uninstalled pytket-1.41.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytket-quantinuum 0.18.0 requires pytket~=1.17, but you have pytket 2.3.2 which is incompatible.
# qnexus 0.20.0 requires pandas<3,>=2, but you have pandas 3.0.1 which is incompatible.
# qnexus 0.20.0 requires quantinuum-schemas<4.0,>=3.2.3, but you have quantinuum-schemas 4.0.0 which is incompatible.
# qnexus 0.20.0 requires rich<14.0,>=13.6, but you have rich 14.3.3 which is incompatible.
# qnexus 0.20.0 requires websockets<14,>11, but you have websockets 16.0 which is incompatible.
# Successfully installed pytket-2.3.2
# Collecting tket2-exts~=0.9.1
#   Using cached tket2_exts-0.9.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: hugr~=0.12.0 in /opt/conda/lib/python3.11/site-packages (from tket2-exts~=0.9.1) (0.12.5)
# Requirement already satisfied: graphviz>=0.20.3 in /opt/conda/lib/python3.11/site-packages (from hugr~=0.12.0->tket2-exts~=0.9.1) (0.20.3)
# Requirement already satisfied: pydantic<2.12,>=2.8 in /opt/conda/lib/python3.11/site-packages (from hugr~=0.12.0->tket2-exts~=0.9.1) (2.11.10)
# Requirement already satisfied: pydantic-extra-types>=2.9.0 in /opt/conda/lib/python3.11/site-packages (from hugr~=0.12.0->tket2-exts~=0.9.1) (2.11.1)
# Requirement already satisfied: semver>=3.0.2 in /opt/conda/lib/python3.11/site-packages (from hugr~=0.12.0->tket2-exts~=0.9.1) (3.0.4)
# Requirement already satisfied: typing-extensions~=4.12 in /opt/conda/lib/python3.11/site-packages (from hugr~=0.12.0->tket2-exts~=0.9.1) (4.15.0)
# Requirement already satisfied: pyzstd<0.18.0,>=0.16.2 in /opt/conda/lib/python3.11/site-packages (from hugr~=0.12.0->tket2-exts~=0.9.1) (0.16.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<2.12,>=2.8->hugr~=0.12.0->tket2-exts~=0.9.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/conda/lib/python3.11/site-packages (from pydantic<2.12,>=2.8->hugr~=0.12.0->tket2-exts~=0.9.1) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<2.12,>=2.8->hugr~=0.12.0->tket2-exts~=0.9.1) (0.4.2)
# Using cached tket2_exts-0.9.2-py3-none-any.whl (18 kB)
# Installing collected packages: tket2-exts
#   Attempting uninstall: tket2-exts
#     Found existing installation: tket2-exts 0.8.0
#     Uninstalling tket2-exts-0.8.0:
#       Successfully uninstalled tket2-exts-0.8.0
# Successfully installed tket2-exts-0.9.2
# Collecting quantinuum-schemas~=3.2.3
#   Using cached quantinuum_schemas-3.2.6-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: orjson<4.0.0,>=3.10.18 in /opt/conda/lib/python3.11/site-packages (from quantinuum-schemas~=3.2.3) (3.11.9)
# Requirement already satisfied: pydantic<3.0.0,>=2.6.0 in /opt/conda/lib/python3.11/site-packages (from quantinuum-schemas~=3.2.3) (2.11.10)
# Requirement already satisfied: pydantic-extra-types<3.0.0,>=2.10.5 in /opt/conda/lib/python3.11/site-packages (from quantinuum-schemas~=3.2.3) (2.11.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.6.0->quantinuum-schemas~=3.2.3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/conda/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.6.0->quantinuum-schemas~=3.2.3) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /opt/conda/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.6.0->quantinuum-schemas~=3.2.3) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.6.0->quantinuum-schemas~=3.2.3) (0.4.2)
# Using cached quantinuum_schemas-3.2.6-py3-none-any.whl (15 kB)
# Installing collected packages: quantinuum-schemas
#   Attempting uninstall: quantinuum-schemas
#     Found existing installation: quantinuum-schemas 4.0.0
#     Uninstalling quantinuum-schemas-4.0.0:
#       Successfully uninstalled quantinuum-schemas-4.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# qnexus 0.20.0 requires pandas<3,>=2, but you have pandas 3.0.1 which is incompatible.
# qnexus 0.20.0 requires rich<14.0,>=13.6, but you have rich 14.3.3 which is incompatible.
# qnexus 0.20.0 requires websockets<14,>11, but you have websockets 16.0 which is incompatible.
# Successfully installed quantinuum-schemas-3.2.6
# Requirement already satisfied: colorama in /opt/conda/lib/python3.11/site-packages (0.4.6)

# %%
# !pip3 install pytket-quantinuum==0.56.2 && pip3 install pytket --upgrade
# Out:
# Collecting pytket-quantinuum==0.56.2
#   Using cached pytket_quantinuum-0.56.2-py3-none-any.whl.metadata (4.9 kB)
# Collecting pytket>=2.9.3 (from pytket-quantinuum==0.56.2)
#   Using cached pytket-2.16.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.7 kB)
# Collecting pytket-qir>=0.25.0 (from pytket-quantinuum==0.56.2)
#   Using cached pytket_qir-1.0.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numpy>=1.26.4 in /opt/conda/lib/python3.11/site-packages (from pytket-quantinuum==0.56.2) (2.2.6)
# Requirement already satisfied: sympy>=1.12.1 in /opt/conda/lib/python3.11/site-packages (from pytket>=2.9.3->pytket-quantinuum==0.56.2) (1.14.0)
# Requirement already satisfied: lark>=1.1.9 in /opt/conda/lib/python3.11/site-packages (from pytket>=2.9.3->pytket-quantinuum==0.56.2) (1.3.1)
# Requirement already satisfied: scipy>=1.13.1 in /opt/conda/lib/python3.11/site-packages (from pytket>=2.9.3->pytket-quantinuum==0.56.2) (1.17.1)
# Requirement already satisfied: networkx>=2.8.8 in /opt/conda/lib/python3.11/site-packages (from pytket>=2.9.3->pytket-quantinuum==0.56.2) (3.6.1)
# Requirement already satisfied: graphviz>=0.20.3 in /opt/conda/lib/python3.11/site-packages (from pytket>=2.9.3->pytket-quantinuum==0.56.2) (0.20.3)
# Requirement already satisfied: jinja2>=3.1.4 in /opt/conda/lib/python3.11/site-packages (from pytket>=2.9.3->pytket-quantinuum==0.56.2) (3.1.4)
# Requirement already satisfied: typing-extensions>=4.12.2 in /opt/conda/lib/python3.11/site-packages (from pytket>=2.9.3->pytket-quantinuum==0.56.2) (4.15.0)
# Requirement already satisfied: qwasm>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from pytket>=2.9.3->pytket-quantinuum==0.56.2) (1.0.1)
# Collecting pyqir~=0.11.1 (from pytket-qir>=0.25.0->pytket-quantinuum==0.56.2)
#   Using cached pyqir-0.11.1-cp39-abi3-manylinux_2_34_x86_64.manylinux_2_35_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2>=3.1.4->pytket>=2.9.3->pytket-quantinuum==0.56.2) (2.1.5)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from qwasm>=1.0.1->pytket>=2.9.3->pytket-quantinuum==0.56.2) (69.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from sympy>=1.12.1->pytket>=2.9.3->pytket-quantinuum==0.56.2) (1.3.0)
# Using cached pytket_quantinuum-0.56.2-py3-none-any.whl (27 kB)
# Using cached pytket-2.16.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (8.3 MB)
# Using cached pytket_qir-1.0.0-py3-none-any.whl (50 kB)
# Using cached pyqir-0.11.1-cp39-abi3-manylinux_2_34_x86_64.manylinux_2_35_x86_64.whl (2.3 MB)
# Installing collected packages: pyqir, pytket, pytket-qir, pytket-quantinuum
#   Attempting uninstall: pyqir
#     Found existing installation: pyqir 0.12.3
#     Uninstalling pyqir-0.12.3:
#       Successfully uninstalled pyqir-0.12.3
#   Attempting uninstall: pytket
#     Found existing installation: pytket 2.3.2
#     Uninstalling pytket-2.3.2:
#       Successfully uninstalled pytket-2.3.2
#   Attempting uninstall: pytket-quantinuum
#     Found existing installation: pytket-quantinuum 0.18.0
#     Uninstalling pytket-quantinuum-0.18.0:
#       Successfully uninstalled pytket-quantinuum-0.18.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# qnexus 0.20.0 requires pandas<3,>=2, but you have pandas 3.0.1 which is incompatible.
# qnexus 0.20.0 requires rich<14.0,>=13.6, but you have rich 14.3.3 which is incompatible.
# qnexus 0.20.0 requires websockets<14,>11, but you have websockets 16.0 which is incompatible.
# Successfully installed pyqir-0.11.1 pytket-2.16.0 pytket-qir-1.0.0 pytket-quantinuum-0.56.2
# Requirement already satisfied: pytket in /opt/conda/lib/python3.11/site-packages (2.16.0)
# Requirement already satisfied: sympy>=1.12.1 in /opt/conda/lib/python3.11/site-packages (from pytket) (1.14.0)
# Requirement already satisfied: numpy>=1.26.4 in /opt/conda/lib/python3.11/site-packages (from pytket) (2.2.6)
# Requirement already satisfied: lark>=1.1.9 in /opt/conda/lib/python3.11/site-packages (from pytket) (1.3.1)
# Requirement already satisfied: scipy>=1.13.1 in /opt/conda/lib/python3.11/site-packages (from pytket) (1.17.1)
# Requirement already satisfied: networkx>=2.8.8 in /opt/conda/lib/python3.11/site-packages (from pytket) (3.6.1)
# Requirement already satisfied: graphviz>=0.20.3 in /opt/conda/lib/python3.11/site-packages (from pytket) (0.20.3)
# Requirement already satisfied: jinja2>=3.1.4 in /opt/conda/lib/python3.11/site-packages (from pytket) (3.1.4)
# Requirement already satisfied: typing-extensions>=4.12.2 in /opt/conda/lib/python3.11/site-packages (from pytket) (4.15.0)
# Requirement already satisfied: qwasm>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from pytket) (1.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2>=3.1.4->pytket) (2.1.5)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from qwasm>=1.0.1->pytket) (69.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from sympy>=1.12.1->pytket) (1.3.0)

# %%
# !python -c "import guppylang; import selene_sim; import qnexus; import pytket; import ecdsa; import numpy; print(dir(selene_sim))"

# %%
# !python -c "import guppylang; import selene_sim; import qnexus; import pytket; import ecdsa; import numpy; print('All core imports OK')"
# Out:
# All core imports OK

# %%
# !pip3 install dwave-ocean-sdk && pip3 install python-dotenv
# Out:
# Collecting dwave-ocean-sdk
#   Using cached dwave_ocean_sdk-9.3.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting dimod==0.12.21 (from dwave-ocean-sdk)
#   Using cached dimod-0.12.21-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.0 kB)
# Collecting dwave-cloud-client==0.14.4 (from dwave-ocean-sdk)
#   Using cached dwave_cloud_client-0.14.4-py3-none-any.whl.metadata (5.4 kB)
# Collecting dwave-gate==0.3.5 (from dwave-ocean-sdk)
#   Using cached dwave_gate-0.3.5-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (18 kB)
# Collecting dwave-hybrid==0.6.15 (from dwave-ocean-sdk)
#   Using cached dwave_hybrid-0.6.15-py3-none-any.whl.metadata (4.5 kB)
# Collecting dwave-inspector==0.5.5 (from dwave-ocean-sdk)
#   Using cached dwave_inspector-0.5.5-py3-none-any.whl.metadata (4.4 kB)
# Collecting dwave-networkx==0.8.18 (from dwave-ocean-sdk)
#   Using cached dwave_networkx-0.8.18-py3-none-any.whl.metadata (2.7 kB)
# Collecting dwave-optimization==0.6.11 (from dwave-ocean-sdk)
#   Using cached dwave_optimization-0.6.11-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (19 kB)
# Collecting dwave-preprocessing==0.6.11 (from dwave-ocean-sdk)
#   Using cached dwave_preprocessing-0.6.11-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.5 kB)
# Collecting dwave-samplers==1.7.0 (from dwave-ocean-sdk)
#   Using cached dwave_samplers-1.7.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Collecting dwave-system==1.34.0 (from dwave-ocean-sdk)
#   Using cached dwave_system-1.34.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting minorminer==0.2.21 (from dwave-ocean-sdk)
#   Using cached minorminer-0.2.21-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (7.9 kB)
# Collecting penaltymodel==1.3.0 (from dwave-ocean-sdk)
#   Using cached penaltymodel-1.3.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: numpy>=1.17.3 in /opt/conda/lib/python3.11/site-packages (from dimod==0.12.21->dwave-ocean-sdk) (2.2.6)
# Requirement already satisfied: requests<3,>=2.25 in /opt/conda/lib/python3.11/site-packages (from requests[socks]<3,>=2.25->dwave-cloud-client==0.14.4->dwave-ocean-sdk) (2.33.1)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/conda/lib/python3.11/site-packages (from dwave-cloud-client==0.14.4->dwave-ocean-sdk) (2.7.0)
# Requirement already satisfied: pydantic<3,>=2 in /opt/conda/lib/python3.11/site-packages (from dwave-cloud-client==0.14.4->dwave-ocean-sdk) (2.11.10)
# Collecting homebase<2,>=1.0 (from dwave-cloud-client==0.14.4->dwave-ocean-sdk)
#   Using cached homebase-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Collecting click<9,>=8.2 (from dwave-cloud-client==0.14.4->dwave-ocean-sdk)
#   Using cached click-8.3.3-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7 in /opt/conda/lib/python3.11/site-packages (from dwave-cloud-client==0.14.4->dwave-ocean-sdk) (2.9.0)
# Collecting plucky<0.5,>=0.4.3 (from dwave-cloud-client==0.14.4->dwave-ocean-sdk)
#   Using cached plucky-0.4.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting diskcache<6,>=5.2.1 (from dwave-cloud-client==0.14.4->dwave-ocean-sdk)
#   Using cached diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: packaging>=19 in /opt/conda/lib/python3.11/site-packages (from dwave-cloud-client==0.14.4->dwave-ocean-sdk) (24.0)
# Collecting werkzeug<4,>=3.1.0 (from dwave-cloud-client==0.14.4->dwave-ocean-sdk)
#   Using cached werkzeug-3.1.8-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: typing-extensions<5,>=4.5.0 in /opt/conda/lib/python3.11/site-packages (from dwave-cloud-client==0.14.4->dwave-ocean-sdk) (4.15.0)
# Collecting authlib<2,>=1.2 (from dwave-cloud-client==0.14.4->dwave-ocean-sdk)
#   Using cached authlib-1.7.2-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: importlib_metadata>=5.0.0 in /opt/conda/lib/python3.11/site-packages (from dwave-cloud-client==0.14.4->dwave-ocean-sdk) (7.1.0)
# Requirement already satisfied: orjson>=3.11 in /opt/conda/lib/python3.11/site-packages (from dwave-cloud-client==0.14.4->dwave-ocean-sdk) (3.11.9)
# Collecting http-sf>=1.0.4 (from dwave-cloud-client==0.14.4->dwave-ocean-sdk)
#   Using cached http_sf-1.2.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from dwave-hybrid==0.6.15->dwave-ocean-sdk) (3.6.1)
# Collecting Flask<4,>=2.2 (from dwave-inspector==0.5.5->dwave-ocean-sdk)
#   Using cached flask-3.1.3-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: scipy>=1.7.3 in /opt/conda/lib/python3.11/site-packages (from dwave-system==1.34.0->dwave-ocean-sdk) (1.17.1)
# Requirement already satisfied: fasteners>=0.15 in /opt/conda/lib/python3.11/site-packages (from minorminer==0.2.21->dwave-ocean-sdk) (0.20)
# Requirement already satisfied: cryptography in /opt/conda/lib/python3.11/site-packages (from authlib<2,>=1.2->dwave-cloud-client==0.14.4->dwave-ocean-sdk) (42.0.7)
# Collecting joserfc>=1.6.0 (from authlib<2,>=1.2->dwave-cloud-client==0.14.4->dwave-ocean-sdk)
#   Using cached joserfc-1.6.5-py3-none-any.whl.metadata (3.2 kB)
# Collecting blinker>=1.9.0 (from Flask<4,>=2.2->dwave-inspector==0.5.5->dwave-ocean-sdk)
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting itsdangerous>=2.2.0 (from Flask<4,>=2.2->dwave-inspector==0.5.5->dwave-ocean-sdk)
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: jinja2>=3.1.2 in /opt/conda/lib/python3.11/site-packages (from Flask<4,>=2.2->dwave-inspector==0.5.5->dwave-ocean-sdk) (3.1.4)
# Requirement already satisfied: markupsafe>=2.1.1 in /opt/conda/lib/python3.11/site-packages (from Flask<4,>=2.2->dwave-inspector==0.5.5->dwave-ocean-sdk) (2.1.5)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.11/site-packages (from importlib_metadata>=5.0.0->dwave-cloud-client==0.14.4->dwave-ocean-sdk) (3.17.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<3,>=2->dwave-cloud-client==0.14.4->dwave-ocean-sdk) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/conda/lib/python3.11/site-packages (from pydantic<3,>=2->dwave-cloud-client==0.14.4->dwave-ocean-sdk) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<3,>=2->dwave-cloud-client==0.14.4->dwave-ocean-sdk) (0.4.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil<3,>=2.7->dwave-cloud-client==0.14.4->dwave-ocean-sdk) (1.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.25->requests[socks]<3,>=2.25->dwave-cloud-client==0.14.4->dwave-ocean-sdk) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.25->requests[socks]<3,>=2.25->dwave-cloud-client==0.14.4->dwave-ocean-sdk) (3.7)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.25->requests[socks]<3,>=2.25->dwave-cloud-client==0.14.4->dwave-ocean-sdk) (2026.2.25)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/conda/lib/python3.11/site-packages (from requests[socks]<3,>=2.25->dwave-cloud-client==0.14.4->dwave-ocean-sdk) (1.7.1)
# Collecting cryptography (from authlib<2,>=1.2->dwave-cloud-client==0.14.4->dwave-ocean-sdk)
#   Using cached cryptography-48.0.0-cp311-abi3-manylinux_2_34_x86_64.whl.metadata (4.3 kB)
# Collecting cffi>=2.0.0 (from cryptography->authlib<2,>=1.2->dwave-cloud-client==0.14.4->dwave-ocean-sdk)
#   Using cached cffi-2.0.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.6 kB)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.11/site-packages (from cffi>=2.0.0->cryptography->authlib<2,>=1.2->dwave-cloud-client==0.14.4->dwave-ocean-sdk) (2.22)
# Using cached dwave_ocean_sdk-9.3.0-py3-none-any.whl (8.4 kB)
# Using cached dimod-0.12.21-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.1 MB)
# Using cached dwave_cloud_client-0.14.4-py3-none-any.whl (167 kB)
# Using cached dwave_gate-0.3.5-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
# Using cached dwave_hybrid-0.6.15-py3-none-any.whl (78 kB)
# Using cached dwave_inspector-0.5.5-py3-none-any.whl (30 kB)
# Using cached dwave_networkx-0.8.18-py3-none-any.whl (106 kB)
# Using cached dwave_optimization-0.6.11-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (15.2 MB)
# Using cached dwave_preprocessing-0.6.11-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.4 MB)
# Using cached dwave_samplers-1.7.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.0 MB)
# Using cached dwave_system-1.34.0-py3-none-any.whl (119 kB)
# Using cached minorminer-0.2.21-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (4.1 MB)
# Using cached penaltymodel-1.3.0-py3-none-any.whl (36 kB)
# Using cached authlib-1.7.2-py2.py3-none-any.whl (259 kB)
# Using cached click-8.3.3-py3-none-any.whl (110 kB)
# Using cached diskcache-5.6.3-py3-none-any.whl (45 kB)
# Using cached flask-3.1.3-py3-none-any.whl (103 kB)
# Using cached homebase-1.0.1-py2.py3-none-any.whl (11 kB)
# Using cached http_sf-1.2.0-py3-none-any.whl (20 kB)
# Using cached plucky-0.4.3-py2.py3-none-any.whl (10 kB)
# Using cached werkzeug-3.1.8-py3-none-any.whl (226 kB)
# Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Using cached joserfc-1.6.5-py3-none-any.whl (70 kB)
# Using cached cryptography-48.0.0-cp311-abi3-manylinux_2_34_x86_64.whl (4.7 MB)
# Using cached cffi-2.0.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (215 kB)
# Installing collected packages: plucky, homebase, werkzeug, itsdangerous, http-sf, dwave-optimization, dwave-gate, diskcache, dimod, click, cffi, blinker, penaltymodel, Flask, dwave-samplers, dwave-preprocessing, dwave-networkx, cryptography, minorminer, joserfc, authlib, dwave-cloud-client, dwave-system, dwave-inspector, dwave-hybrid, dwave-ocean-sdk
#   Attempting uninstall: click
#     Found existing installation: click 8.1.8
#     Uninstalling click-8.1.8:
#       Successfully uninstalled click-8.1.8
#   Attempting uninstall: cffi
#     Found existing installation: cffi 1.16.0
#     Uninstalling cffi-1.16.0:
#       Successfully uninstalled cffi-1.16.0
#   Attempting uninstall: blinker
#     Found existing installation: blinker 1.8.2
#     Uninstalling blinker-1.8.2:
#       Successfully uninstalled blinker-1.8.2
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 42.0.7
#     Uninstalling cryptography-42.0.7:
#       Successfully uninstalled cryptography-42.0.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# qnexus 0.20.0 requires pandas<3,>=2, but you have pandas 3.0.1 which is incompatible.
# qnexus 0.20.0 requires rich<14.0,>=13.6, but you have rich 14.3.3 which is incompatible.
# qnexus 0.20.0 requires websockets<14,>11, but you have websockets 16.0 which is incompatible.
# qbraid-cli 0.12.0a5 requires click<=8.1.8, but you have click 8.3.3 which is incompatible.
# pyopenssl 24.0.0 requires cryptography<43,>=41.0.5, but you have cryptography 48.0.0 which is incompatible.
# Successfully installed Flask-3.1.3 authlib-1.7.2 blinker-1.9.0 cffi-2.0.0 click-8.3.3 cryptography-48.0.0 dimod-0.12.21 diskcache-5.6.3 dwave-cloud-client-0.14.4 dwave-gate-0.3.5 dwave-hybrid-0.6.15 dwave-inspector-0.5.5 dwave-networkx-0.8.18 dwave-ocean-sdk-9.3.0 dwave-optimization-0.6.11 dwave-preprocessing-0.6.11 dwave-samplers-1.7.0 dwave-system-1.34.0 homebase-1.0.1 http-sf-1.2.0 itsdangerous-2.2.0 joserfc-1.6.5 minorminer-0.2.21 penaltymodel-1.3.0 plucky-0.4.3 werkzeug-3.1.8
# Requirement already satisfied: python-dotenv in /opt/conda/lib/python3.11/site-packages (1.2.2)

# %%
# !pip3 install dwave-neal
# Out:
# Collecting dwave-neal
#   Using cached dwave_neal-0.6.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: dwave-samplers<2.0.0,>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from dwave-neal) (1.7.0)
# Requirement already satisfied: numpy<3.0.0,>=1.21.6 in /opt/conda/lib/python3.11/site-packages (from dwave-samplers<2.0.0,>=1.0.0->dwave-neal) (2.2.6)
# Requirement already satisfied: dimod<0.13.0,>=0.12.21 in /opt/conda/lib/python3.11/site-packages (from dwave-samplers<2.0.0,>=1.0.0->dwave-neal) (0.12.21)
# Requirement already satisfied: networkx>=3.0 in /opt/conda/lib/python3.11/site-packages (from dwave-samplers<2.0.0,>=1.0.0->dwave-neal) (3.6.1)
# Using cached dwave_neal-0.6.0-py3-none-any.whl (8.7 kB)
# Installing collected packages: dwave-neal
# Successfully installed dwave-neal-0.6.0

# %%
# !pip3 install pytket-iqm && pip3 install pytket-qiskit
# Out:
# Collecting pytket-iqm
#   Using cached pytket_iqm-0.18.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pytket>=2.11.0 in /opt/conda/lib/python3.11/site-packages (from pytket-iqm) (2.16.0)
# Collecting iqm-client~=22.3 (from pytket-iqm)
#   Using cached iqm_client-22.16-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.2 in /opt/conda/lib/python3.11/site-packages (from iqm-client~=22.3->pytket-iqm) (2.2.6)
# Collecting packaging==24.1 (from iqm-client~=22.3->pytket-iqm)
#   Using cached packaging-24.1-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: pydantic<3.0,>=2.9.2 in /opt/conda/lib/python3.11/site-packages (from iqm-client~=22.3->pytket-iqm) (2.11.10)
# Collecting requests==2.32.3 (from iqm-client~=22.3->pytket-iqm)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests==2.32.3->iqm-client~=22.3->pytket-iqm) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests==2.32.3->iqm-client~=22.3->pytket-iqm) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests==2.32.3->iqm-client~=22.3->pytket-iqm) (2.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests==2.32.3->iqm-client~=22.3->pytket-iqm) (2026.2.25)
# Requirement already satisfied: sympy>=1.12.1 in /opt/conda/lib/python3.11/site-packages (from pytket>=2.11.0->pytket-iqm) (1.14.0)
# Requirement already satisfied: lark>=1.1.9 in /opt/conda/lib/python3.11/site-packages (from pytket>=2.11.0->pytket-iqm) (1.3.1)
# Requirement already satisfied: scipy>=1.13.1 in /opt/conda/lib/python3.11/site-packages (from pytket>=2.11.0->pytket-iqm) (1.17.1)
# Requirement already satisfied: networkx>=2.8.8 in /opt/conda/lib/python3.11/site-packages (from pytket>=2.11.0->pytket-iqm) (3.6.1)
# Requirement already satisfied: graphviz>=0.20.3 in /opt/conda/lib/python3.11/site-packages (from pytket>=2.11.0->pytket-iqm) (0.20.3)
# Requirement already satisfied: jinja2>=3.1.4 in /opt/conda/lib/python3.11/site-packages (from pytket>=2.11.0->pytket-iqm) (3.1.4)
# Requirement already satisfied: typing-extensions>=4.12.2 in /opt/conda/lib/python3.11/site-packages (from pytket>=2.11.0->pytket-iqm) (4.15.0)
# Requirement already satisfied: qwasm>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from pytket>=2.11.0->pytket-iqm) (1.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2>=3.1.4->pytket>=2.11.0->pytket-iqm) (2.1.5)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<3.0,>=2.9.2->iqm-client~=22.3->pytket-iqm) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/conda/lib/python3.11/site-packages (from pydantic<3.0,>=2.9.2->iqm-client~=22.3->pytket-iqm) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<3.0,>=2.9.2->iqm-client~=22.3->pytket-iqm) (0.4.2)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from qwasm>=1.0.1->pytket>=2.11.0->pytket-iqm) (69.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from sympy>=1.12.1->pytket>=2.11.0->pytket-iqm) (1.3.0)
# Using cached pytket_iqm-0.18.0-py3-none-any.whl (21 kB)
# Using cached iqm_client-22.16-py3-none-any.whl (143 kB)
# Using cached packaging-24.1-py3-none-any.whl (53 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Installing collected packages: requests, packaging, iqm-client, pytket-iqm
#   Attempting uninstall: requests
#     Found existing installation: requests 2.33.1
#     Uninstalling requests-2.33.1:
#       Successfully uninstalled requests-2.33.1
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# qiskit-ibm-runtime 0.46.1 requires requests>=2.32.4, but you have requests 2.32.3 which is incompatible.
# ibm-cloud-sdk-core 3.24.4 requires requests<3.0.0,>=2.32.4, but you have requests 2.32.3 which is incompatible.
# qbraid-cli 0.12.0a5 requires click<=8.1.8, but you have click 8.3.3 which is incompatible.
# cirq-core 1.4.1 requires numpy~=1.22, but you have numpy 2.2.6 which is incompatible.
# Successfully installed iqm-client-22.16 packaging-24.1 pytket-iqm-0.18.0 requests-2.32.3
# Collecting pytket-qiskit
#   Using cached pytket_qiskit-0.77.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pytket>=2.11.0 in /opt/conda/lib/python3.11/site-packages (from pytket-qiskit) (2.16.0)
# Requirement already satisfied: qiskit>=2.3 in /opt/conda/lib/python3.11/site-packages (from pytket-qiskit) (2.4.1)
# Requirement already satisfied: qiskit-ibm-runtime>=0.43.1 in /opt/conda/lib/python3.11/site-packages (from pytket-qiskit) (0.46.1)
# Requirement already satisfied: qiskit-aer>=0.17.1 in /opt/conda/lib/python3.11/site-packages (from pytket-qiskit) (0.17.2)
# Requirement already satisfied: numpy>=1.26.4 in /opt/conda/lib/python3.11/site-packages (from pytket-qiskit) (2.2.6)
# Collecting symengine>=0.11 (from pytket-qiskit)
#   Using cached symengine-0.14.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: sympy>=1.12.1 in /opt/conda/lib/python3.11/site-packages (from pytket>=2.11.0->pytket-qiskit) (1.14.0)
# Requirement already satisfied: lark>=1.1.9 in /opt/conda/lib/python3.11/site-packages (from pytket>=2.11.0->pytket-qiskit) (1.3.1)
# Requirement already satisfied: scipy>=1.13.1 in /opt/conda/lib/python3.11/site-packages (from pytket>=2.11.0->pytket-qiskit) (1.17.1)
# Requirement already satisfied: networkx>=2.8.8 in /opt/conda/lib/python3.11/site-packages (from pytket>=2.11.0->pytket-qiskit) (3.6.1)
# Requirement already satisfied: graphviz>=0.20.3 in /opt/conda/lib/python3.11/site-packages (from pytket>=2.11.0->pytket-qiskit) (0.20.3)
# Requirement already satisfied: jinja2>=3.1.4 in /opt/conda/lib/python3.11/site-packages (from pytket>=2.11.0->pytket-qiskit) (3.1.4)
# Requirement already satisfied: typing-extensions>=4.12.2 in /opt/conda/lib/python3.11/site-packages (from pytket>=2.11.0->pytket-qiskit) (4.15.0)
# Requirement already satisfied: qwasm>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from pytket>=2.11.0->pytket-qiskit) (1.0.1)
# Requirement already satisfied: rustworkx>=0.15.0 in /opt/conda/lib/python3.11/site-packages (from qiskit>=2.3->pytket-qiskit) (0.17.1)
# Requirement already satisfied: dill>=0.3 in /opt/conda/lib/python3.11/site-packages (from qiskit>=2.3->pytket-qiskit) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/conda/lib/python3.11/site-packages (from qiskit>=2.3->pytket-qiskit) (5.7.0)
# Requirement already satisfied: psutil>=5 in /opt/conda/lib/python3.11/site-packages (from qiskit-aer>=0.17.1->pytket-qiskit) (5.9.8)
# Requirement already satisfied: python-dateutil>=2.8.0 in /opt/conda/lib/python3.11/site-packages (from qiskit-aer>=0.17.1->pytket-qiskit) (2.9.0)
# Collecting requests>=2.32.4 (from qiskit-ibm-runtime>=0.43.1->pytket-qiskit)
#   Using cached requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: requests-ntlm>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from qiskit-ibm-runtime>=0.43.1->pytket-qiskit) (1.3.0)
# Requirement already satisfied: urllib3>=2.4.0 in /opt/conda/lib/python3.11/site-packages (from qiskit-ibm-runtime>=0.43.1->pytket-qiskit) (2.7.0)
# Requirement already satisfied: ibm-platform-services>=0.55.3 in /opt/conda/lib/python3.11/site-packages (from qiskit-ibm-runtime>=0.43.1->pytket-qiskit) (0.75.0)
# Requirement already satisfied: ibm-quantum-schemas>=0.5.20260320 in /opt/conda/lib/python3.11/site-packages (from qiskit-ibm-runtime>=0.43.1->pytket-qiskit) (0.7.20260419)
# Requirement already satisfied: pydantic>=2.7.0 in /opt/conda/lib/python3.11/site-packages (from qiskit-ibm-runtime>=0.43.1->pytket-qiskit) (2.11.10)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from qiskit-ibm-runtime>=0.43.1->pytket-qiskit) (24.1)
# Requirement already satisfied: pybase64>=1.4 in /opt/conda/lib/python3.11/site-packages (from qiskit-ibm-runtime>=0.43.1->pytket-qiskit) (1.4.3)
# Requirement already satisfied: samplomatic>=0.13.0 in /opt/conda/lib/python3.11/site-packages (from qiskit-ibm-runtime>=0.43.1->pytket-qiskit) (0.18.0)
# Requirement already satisfied: ibm_cloud_sdk_core<4.0.0,>=3.24.4 in /opt/conda/lib/python3.11/site-packages (from ibm-platform-services>=0.55.3->qiskit-ibm-runtime>=0.43.1->pytket-qiskit) (3.24.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2>=3.1.4->pytket>=2.11.0->pytket-qiskit) (2.1.5)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from pydantic>=2.7.0->qiskit-ibm-runtime>=0.43.1->pytket-qiskit) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/conda/lib/python3.11/site-packages (from pydantic>=2.7.0->qiskit-ibm-runtime>=0.43.1->pytket-qiskit) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from pydantic>=2.7.0->qiskit-ibm-runtime>=0.43.1->pytket-qiskit) (0.4.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.0->qiskit-aer>=0.17.1->pytket-qiskit) (1.16.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from qwasm>=1.0.1->pytket>=2.11.0->pytket-qiskit) (69.5.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.32.4->qiskit-ibm-runtime>=0.43.1->pytket-qiskit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests>=2.32.4->qiskit-ibm-runtime>=0.43.1->pytket-qiskit) (3.7)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/conda/lib/python3.11/site-packages (from requests>=2.32.4->qiskit-ibm-runtime>=0.43.1->pytket-qiskit) (2026.2.25)
# Requirement already satisfied: cryptography>=1.3 in /opt/conda/lib/python3.11/site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime>=0.43.1->pytket-qiskit) (48.0.0)
# Requirement already satisfied: pyspnego>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime>=0.43.1->pytket-qiskit) (0.12.1)
# Requirement already satisfied: orjson>=3.9.0 in /opt/conda/lib/python3.11/site-packages (from samplomatic>=0.13.0->qiskit-ibm-runtime>=0.43.1->pytket-qiskit) (3.11.9)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from sympy>=1.12.1->pytket>=2.11.0->pytket-qiskit) (1.3.0)
# Requirement already satisfied: cffi>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime>=0.43.1->pytket-qiskit) (2.0.0)
# Requirement already satisfied: PyJWT<3.0.0,>=2.11.0 in /opt/conda/lib/python3.11/site-packages (from ibm_cloud_sdk_core<4.0.0,>=3.24.4->ibm-platform-services>=0.55.3->qiskit-ibm-runtime>=0.43.1->pytket-qiskit) (2.12.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.11/site-packages (from cffi>=2.0.0->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime>=0.43.1->pytket-qiskit) (2.22)
# Using cached pytket_qiskit-0.77.0-py3-none-any.whl (90 kB)
# Using cached symengine-0.14.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (50.4 MB)
# Using cached requests-2.33.1-py3-none-any.whl (64 kB)
# Installing collected packages: symengine, requests, pytket-qiskit
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# iqm-client 22.16 requires requests==2.32.3, but you have requests 2.33.1 which is incompatible.
# qbraid-cli 0.12.0a5 requires click<=8.1.8, but you have click 8.3.3 which is incompatible.
# Successfully installed pytket-qiskit-0.77.0 requests-2.33.1 symengine-0.14.1

# %%
# !pip3 install scipy && pip3 install scikit-learn
# Out:
# Requirement already satisfied: scipy in /opt/conda/lib/python3.11/site-packages (1.17.1)
# Requirement already satisfied: numpy<2.7,>=1.26.4 in /opt/conda/lib/python3.11/site-packages (from scipy) (2.2.6)
# Collecting scikit-learn
#   Using cached scikit_learn-1.8.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in /opt/conda/lib/python3.11/site-packages (from scikit-learn) (2.2.6)
# Requirement already satisfied: scipy>=1.10.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn) (1.17.1)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Using cached scikit_learn-1.8.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (9.1 MB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.5.3 scikit-learn-1.8.0 threadpoolctl-3.6.0

# %%
# !git clone https://github.com/threealgos/Quantum_KeySpace-Reducer.git

# %%
IGNORE__FOR__NOW -> !dwave config create --full
# Out:
#   Cell In[28], line 1
#     IGNORE__FOR__NOW -> !dwave config create --full
#                      ^
# SyntaxError: invalid syntax

# %%
IGNORE__FOR__NOW -> !dwave setup --auth

# %%
# !NOW_OPEN_NEW_WINDOW_TERMINAL And type ---> cd Quantum_KeySpace-Reducer && python3 Q-Probabilistic_KeySpace_Reducer_V1.py
